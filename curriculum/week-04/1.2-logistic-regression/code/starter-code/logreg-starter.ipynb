# %%
# reserve the first cell, to import all dependencies (python classes) that you will need

import numpy as np
import pandas as pd
import statsmodels.api as sm

# %%
# keep all functions in one cell, call them when you need them. 
def read_file(path): # path = dynamic input parameter
    return pd.read_csv(path, header = None)

# %%
# use function to read in cancer Dataset. 
path = "https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/wdbc.data"
df = read_file(path)

# %%
# find data dictionary of df
df.head()

df.columns = [ 'ID number', 'Diagnosis', 'radius', 'texture', 'perimeter', 'area', 'smoothness', 'compactness', 'concavity','concave_points', 'symetery', 'fractal_dimension', 'se_radius', 'se_texture', 'se_perimeter', 'se_area', 'smoothness', 'compactness', 'concavity','se_concave_points', 'se_symetery', 'se_fractal_dimension', 'l_radius', 'l_texture', 'l_perimeter', 'l_area', 'smoothness', 'compactness', 'concavity','l_concave_points', 'l_symetery', 'l_fractal_dimension']
df.head()
# Out:
#    ID number Diagnosis  radius  texture  perimeter    area  smoothness  \
# 0     842302         M   17.99    10.38     122.80  1001.0     0.11840
# 1     842517         M   20.57    17.77     132.90  1326.0     0.08474
# 2   84300903         M   19.69    21.25     130.00  1203.0     0.10960
# 3   84348301         M   11.42    20.38      77.58   386.1     0.14250
# 4   84358402         M   20.29    14.34     135.10  1297.0     0.10030
#
#    compactness  concavity  concave_points         ...           l_radius  \
# 0      0.27760     0.3001         0.14710         ...              25.38
# 1      0.07864     0.0869         0.07017         ...              24.99
# 2      0.15990     0.1974         0.12790         ...              23.57
# 3      0.28390     0.2414         0.10520         ...              14.91
# 4      0.13280     0.1980         0.10430         ...              22.54
#
#    l_texture  l_perimeter  l_area  smoothness  compactness  concavity  \
# ...

# %%
# Obtain the first 10 features, which are the mean figures in the dataset, 
# call your dataFrame with only the features, data_df, and  the dataframe with only 
# the outcome ( or response/label) target_df

data_df = df.iloc[:, 2:12]
data_df.head()
# Out:
#    radius  texture  perimeter    area  smoothness  compactness  concavity  \
# 0   17.99    10.38     122.80  1001.0     0.11840      0.27760     0.3001
# 1   20.57    17.77     132.90  1326.0     0.08474      0.07864     0.0869
# 2   19.69    21.25     130.00  1203.0     0.10960      0.15990     0.1974
# 3   11.42    20.38      77.58   386.1     0.14250      0.28390     0.2414
# 4   20.29    14.34     135.10  1297.0     0.10030      0.13280     0.1980
#
#    concave_points  symetery  fractal_dimension
# 0         0.14710    0.2419            0.07871
# 1         0.07017    0.1812            0.05667
# 2         0.12790    0.2069            0.05999
# 3         0.10520    0.2597            0.09744
# 4         0.10430    0.1809            0.05883

# %%
target_df = df.iloc[:, 1:2]

#target_df = pd.get_dummies(target_df["Diagnosis"], prefix="Diagnosis")
target_df.head()
# Out:
#   Diagnosis
# 0         M
# 1         M
# 2         M
# 3         M
# 4         M

# %%
# Convert DataFrame to Numpy Array
x = data_df.as_matrix(columns=None)
y = target_df.as_matrix(columns=None)

# %%
#Normalize all the features data.
#nc = [x for x in wine.columns if x != 'red_wine']

data_df.ix[:, :] = (data_df.ix[:,:] - data_df.ix[:,:].mean())\
                   / data_df.ix[:,:].std()

# %%
print y
# Out:
# [['M']
#  ['M']
#  ['M']
#  ['M']
#  ['M']
#  ['M']
#  ['M']
#  ['M']
#  ['M']
#  ['M']
#  ['M']
#  ['M']
#  ['M']
#  ['M']
#  ['M']
#  ['M']
#  ['M']
#  ['M']
#  ['M']
#  ['B']
#  ['B']
#  ['B']
#  ['M']
#  ['M']
#  ['M']
#  ['M']
#  ['M']
#  ['M']
#  ['M']
#  ['M']
#  ['M']
#  ['M']
#  ['M']
#  ['M']
#  ['M']
#  ['M']
#  ['M']
#  ['B']
#  ['M']
#  ['M']
#  ['M']
#  ['M']
#  ['M']
#  ['M']
#  ['M']
#  ['M']
#  ['B']
#  ['M']
#  ['B']
#  ['B']
#  ['B']
#  ['B']
#  ['B']
#  ['M']
#  ['M']
#  ['B']
#  ['M']
#  ['M']
#  ['B']
#  ['B']
#  ['B']
#  ['B']
#  ['M']
#  ['B']
#  ['M']
#  ['M']
#  ['B']
#  ['B']
#  ['B']
#  ['B']
#  ['M']
#  ['B']
#  ['M']
#  ['M']
#  ['B']
#  ['M']
#  ['B']
#  ['M']
#  ['M']
#  ['B']
#  ['B']
#  ['B']
#  ['M']
#  ['M']
#  ['B']
#  ['M']
#  ['M']
#  ['M']
#  ['B']
#  ['B']
#  ['B']
#  ['M']
#  ['B']
#  ['B']
#  ['M']
#  ['M']
#  ['B']
#  ['B']
#  ['B']
#  ['M']
#  ['M']
#  ['B']
#  ['B']
#  ['B']
#  ['B']
#  ['M']
#  ['B']
#  ['B']
#  ['M']
#  ['B']
#  ['B']
# ...

# %%
### specify the model, call the final fit, md1_fit, hint use MNLogit from class SM, 
# and call the .fit() method on the object


logit = sm.Logit(target_df["Diagnosis"], data_df)
md1_fit = logit.fit()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-8f9c37d4ea8f> in <module>()
#       3
#       4
# ----> 5 logit = sm.Logit(target_df["Diagnosis"], data_df)
#       6 md1_fit = logit.fit()
#
# /Users/timothyernst/anaconda/envs/Python2/lib/python2.7/site-packages/statsmodels/discrete/discrete_model.pyc in __init__(self, endog, exog, **kwargs)
#     399
#     400     def __init__(self, endog, exog, **kwargs):
# --> 401         super(BinaryModel, self).__init__(endog, exog, **kwargs)
#     402         if (self.__class__.__name__ != 'MNLogit' and
#     403                 not np.all((self.endog >= 0) & (self.endog <= 1))):
#
# /Users/timothyernst/anaconda/envs/Python2/lib/python2.7/site-packages/statsmodels/discrete/discrete_model.pyc in __init__(self, endog, exog, **kwargs)
#     152     """
#     153     def __init__(self, endog, exog, **kwargs):
# ...

# %%
### print model summary ###
result.summary2()

# %%
### print the aic and bic metrics ###

# %%
### get the marginal effects of your fitted model md1_fit ###
mdl_margeff = mdl_fit.get_margeff()

# %%
mdl_margeff.summary()
