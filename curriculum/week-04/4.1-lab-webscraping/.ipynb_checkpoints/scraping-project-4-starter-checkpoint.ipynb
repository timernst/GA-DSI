# %% [markdown]
# # ![](https://ga-dash.s3.amazonaws.com/production/assets/logo-9f88ae6c9c3871690e33280fcf557f33.png) Webscraping Project 4 Lab
#
# Week 4 | Day 4

# %% [markdown]
# In this project, we will practice two major skills: collecting data by scraping a website and then building a binary predictor with Logistic Regression.
#
# We are going to collect salary information on data science jobs in a variety of markets. Then using the location, title and summary of the job we will attempt to predict the salary of the job. For job posting sites, this would be extraordinarily useful. While most listings DO NOT come with salary information (as you will see in this exercise), being to able extrapolate or predict the expected salaries from other listings can help guide negotiations.
#
# Normally, we could use regression for this task; however, we will convert this problem into classification and use Logistic Regression.
#
# - Question: Why would we want this to be a classification problem?
# - Answer: While more precision may be better, there is a fair amount of natural variance in job salaries - predicting a range be may be useful.
#
# Therefore, the first part of the assignment will be focused on scraping Indeed.com (or other sites at your team's discretion). In the second part, the focus is on using listings with salary information to build a model and predict high or low salaries and what features are predictive of that result.

# %% [markdown]
# ### Scraping job listings from Indeed.com

# %% [markdown]
# We will be scraping job listings from Indeed.com using BeautifulSoup. Luckily, Indeed.com is a simple text page where we can easily find relevant entries.
#
# First, look at the source of an Indeed.com page: (http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10")
#
# Notice, each job listing is underneath a `div` tag with a class name of `result`. We can use BeautifulSoup to extract those.

# %% [markdown]
# #### Setup a request (using `requests`) to the URL below. Use BeautifulSoup to parse the page and extract all results (HINT: Look for div tags with class name result)

# %%
URL = "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10"

# %%
import requests
import bs4
from bs4 import BeautifulSoup

# %%
## YOUR CODE HERE

r2 = requests.get('https://www.dice.com/jobs/jtype-Full%20Time-q-data_science-limit-30-l-New_York%2C_NY-radius-30-jobs.html?searchid=3891919361279')

soup = BeautifulSoup(r2.content, "lxml")

# %%
soup
# Out:
# <!DOCTYPE html>\n<html>\n<head>\n<meta charset="unicode-escape"/>\n<meta content="IE=edge" http-equiv="X-UA-Compatible"/>\n<meta content="width=device-width, initial-scale=1" name="viewport"/>\n<meta content="Job_Search_Results" name="ompagename"/>\n<meta content="tech pro" name="channel"/>\n<title>Full-Time data science jobs in New York, NY | Dice.com</title>\n<meta content="2,963 Full-Time data science jobs in New York, NY on Dice.com. Find your next tech job." name="description"/>\n<meta content="Full-Time data science jobs in New York, NY, tech jobs, it jobs, recruitment,  careers,  employment,  job listings,  job search,  search engine, work in" name="keywords"/>\n<link href="https://www.dice.com/jobs/q-data_science-jtype-Full+Time-limit-30-l-New_York%2C_NY-radius-30-jobs.html" rel="canonical"/>\n<link href="https://www.dice.com/jobs/q-data_science-jtype-Full+Time-limit-30-l-New_York%2C_NY-radius-30-startPage-2-jobs.html" rel="next"/>\n<link href="//fonts.googleapis.com/css?family=Roboto+Condensed" rel="stylesheet"/>\n<link href="//assets.dice.com/techpro/img/favicons/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>\n<link href="//assets.dice.com/techpro/img/favicons/apple-touch-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>\n<link href="//assets.dice.com/techpro/img/favicons/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>\n<link href="//assets.dice.com/techpro/img/favicons/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>\n<link href="//assets.dice.com/techpro/img/favicons/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>\n<link href="//assets.dice.com/techpro/img/favicons/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>\n<link href="//assets.dice.com/techpro/img/favicons/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>\n<link href="//assets.dice.com/techpro/img/favicons/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>\n<link href="//assets.dice.com/techpro/img/favicons/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>\n<link href="//assets.dice.com/techpro/img/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>\n<link href="//assets.dice.com/techpro/img/favicons/favicon-194x194.png" rel="icon" sizes="194x194" type="image/png"/>\n<link href="//assets.dice.com/techpro/img/favicons/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>\n<link href="//assets.dice.com/techpro/img/favicons/android-chrome-192x192.png" rel="icon" sizes="192x192" type="image/png"/>\n<link href="//assets.dice.com/techpro/img/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>\n<link href="//assets.dice.com/techpro/img/favicons/manifest.json" rel="manifest"/>\n<link href="//assets.dice.com/techpro/img/favicons/favicon.ico" rel="shortcut icon"/>\n<meta content="Dice" name="apple-mobile-web-app-title"/>\n<meta content="Dice" name="application-name"/>\n<meta content="#cc0000" name="msapplication-TileColor"/>\n<meta content="//assets.dice.com/techpro/img/favicons/mstile-144x144.png" name="msapplication-TileImage"/>\n<meta content="//assets.dice.com/techpro/img/favicons/browserconfig.xml" name="msapplication-config"/>\n<meta content="#cc0000" name="theme-color"/>\n<script type="text/javascript">var signFromGoogleOutVal = false;</script>\n<link href="//assets.dice.com/techpro/css/job-search.min.css" rel="stylesheet"/>\n<script src="//assets.adobedtm.com/8c06f57f0590fbbe830e2dd0366687c0599684e7/satelliteLib-73044e29039c50f90968e5135f6f50a83641e7f0.js"></script>\n<!-- Begin Monetate tag v6. Place at start of document head. DO NOT ALTER. -->\n<script type="text/javascript">\n    var monetateT = new Date().getTime();\n    (function() {\n        var p = document.location.protocol;\n        if (p == "http:" || p == "https:") {\n            if (true === true) {//For PROD & QA\n                var m = document.createElement('script'); m.type = 'te ...

# %% [markdown]
# Let's look at one result more closely. A single `result` looks like
#
# ```
# <div class=" row result" data-jk="2480d203f7e97210" data-tn-component="organicJob" id="p_2480d203f7e97210" itemscope="" itemtype="http://schema.org/JobPosting">
# <h2 class="jobtitle" id="jl_2480d203f7e97210">
# <a class="turnstileLink" data-tn-element="jobTitle" onmousedown="return rclk(this,jobmap[0],1);" rel="nofollow" target="_blank" title="AVP/Quantitative Analyst">AVP/Quantitative Analyst</a>
# </h2>
# <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">
# <span itemprop="name">
# <a href="/cmp/Alliancebernstein?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=2480d203f7e97210&amp;jcid=b374f2a780e04789" target="_blank">
#     AllianceBernstein</a></span>
# </span>
# <tr>
# <td class="snip">
# <nobr>$117,500 - $127,500 a year</nobr>
# <div>
# <span class="summary" itemprop="description">
# C onduct quantitative and statistical research as well as portfolio management for various investment portfolios. Collaborate with Quantitative Analysts and</span>
# </div>
# </div>
# </td>
# </tr>
# </table>
# </div>
# ```
#
# While this has some more verbose elements removed, we can see that there is some structure to the above:
# - The salary is available in a `nobr` element inside of a `td` element with `class='snip`.
# - The title of a job is in a link with class set to `jobtitle` and a `data-tn-element="jobTitle`.
# - The location is set in a `span` with `class='location'`.
# - The company is set in a `span` with `class='company'`.

# %% [markdown]
# ### Write 4 functions to extract each item: location, company, job, and salary.
#
# example:
# ```python
# def extract_location_from_result(result):
#     return result.find ...
# ```
#
#
# - Make sure these functions are robust and can handle cases where the data/field may not be available.
# - Test the functions on the results above
# - Include any other features you may want to use later (e.g. summary, #of reviews...)

# %%
print soup.prettify()
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="Job_Search_Results" name="ompagename"/>
#   <meta content="tech pro" name="channel"/>
#   <title>
#    Full-Time data science jobs in New York, NY | Dice.com
#   </title>
#   <meta content="2,963 Full-Time data science jobs in New York, NY on Dice.com. Find your next tech job." name="description"/>
#   <meta content="Full-Time data science jobs in New York, NY, tech jobs, it jobs, recruitment,  careers,  employment,  job listings,  job search,  search engine, work in" name="keywords"/>
#   <link href="https://www.dice.com/jobs/q-data_science-jtype-Full+Time-limit-30-l-New_York%2C_NY-radius-30-jobs.html" rel="canonical"/>
#   <link href="https://www.dice.com/jobs/q-data_science-jtype-Full+Time-limit-30-l-New_York%2C_NY-radius-30-startPage-2-jobs.html" rel="next"/>
#   <link href="//fonts.googleapis.com/css?family=Roboto+Condensed" rel="stylesheet"/>
#   <link href="//assets.dice.com/techpro/img/favicons/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
#   <link href="//assets.dice.com/techpro/img/favicons/apple-touch-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
#   <link href="//assets.dice.com/techpro/img/favicons/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
#   <link href="//assets.dice.com/techpro/img/favicons/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
#   <link href="//assets.dice.com/techpro/img/favicons/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
#   <link href="//assets.dice.com/techpro/img/favicons/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
#   <link href="//assets.dice.com/techpro/img/favicons/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
#   <link href="//assets.dice.com/techpro/img/favicons/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
#   <link href="//assets.dice.com/techpro/img/favicons/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="//assets.dice.com/techpro/img/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="//assets.dice.com/techpro/img/favicons/favicon-194x194.png" rel="icon" sizes="194x194" type="image/png"/>
#   <link href="//assets.dice.com/techpro/img/favicons/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
#   <link href="//assets.dice.com/techpro/img/favicons/android-chrome-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
#   <link href="//assets.dice.com/techpro/img/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="//assets.dice.com/techpro/img/favicons/manifest.json" rel="manifest"/>
#   <link href="//assets.dice.com/techpro/img/favicons/favicon.ico" rel="shortcut icon"/>
#   <meta content="Dice" name="apple-mobile-web-app-title"/>
#   <meta content="Dice" name="application-name"/>
#   <meta content="#cc0000" name="msapplication-TileColor"/>
#   <meta content="//assets.dice.com/techpro/img/favicons/mstile-144x144.png" name="msapplication-TileImage"/>
#   <meta content="//assets.dice.com/techpro/img/favicons/browserconfig.xml" name="msapplication-config"/>
#   <meta content="#cc0000" name="theme-color"/>
#   <script type="text/javascript">
#    var signFromGoogleOutVal = false;
#   </script>
#   <link href="//assets.dice.com/techpro/css/job-search.min.css" rel="stylesheet"/>
#   <script src="//assets.adobedtm.com/8c06f57f0590fbbe830e2dd0366687c0599684e7/satelliteLib-73044e29039c50f90968e5135f6f50a83641e7f0.js">
#   </script>
#   <!-- Begin Monetate tag v6. Place at start of document head. DO NOT ALTER. -->
#   <script type="text/javascript">
#    var monetateT = new Date().getTime();
#     (function() {
#         var p = document.location.protocol;
#         if (p == "http:" || p == "https:") {
#             if (true === true) {//For PROD & QA
#                 var m = document.createElement('script'); m.type = 'text/javascript'; m.async = true; m.src = (p == "https:" ? "https://s" : "http://") + "b.monetate.net/js/1/a-49445784/p/dice.com/" + Math.floor((monetateT + 1615620) / 3600000) + "/g";
#                 var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(m, s);
#             } else {//Only for PILOT
#                 var m = document.createElement("script"); m.type = "text/javascript"; m.src = (p == "https:" ? "https://s" : "http://") + "e.monetate.net/js/2/a-49445784/d/dicepilot.com/entry.js";
#                 var e = document.createElement("div"); e.appendChild(m); document.write(e.innerHTML);
#             }
#         }
#     })();
#   </script>
#   <!-- End Monetate tag. -->
#   <script type="text/javascript">
#    var diceJSON = {page : 1, pageCount : 99 , limit : 30} ;
# 		/* function errorImg(obj) {
# 			console.log("obj.src == "+obj.src);
# 			$(obj).hide();
# 			$(obj).parent().siblings('.circle').show();
# 		} */
#   </script>
#  </head>
#  <body>
#   <!--JS required parameter Start-->
#   <input id="sort" name="sort" type="hidden" value=""/>
#   <input id="searchType" name="searchType" type="hidden" value="basic"/>
#   <input id="pageNo" name="pageNo" type="hidden" value="1"/>
#   <input id="loc" name="loc" type="hidden" value="New York, NY"/>
#   <input id="savesearch" type="hidden" value="false"/>
#   <input id="newSearch" type="hidden" value="false"/>
#   <input id="rJobFlag" type="hidden" value="false"/>
#   <input id="hideViewedJobsEnable" type="hidden" value="false"/>
#   <!--
# -->
#   <input id="jtype" name="jtype" type="hidden" value="Full Time"/>
#   <input id="radius" name="radius" type="hidden" value="30"/>
#   <!--JS required parameter End-->
#   <!--Company Logo required parameter Start-->
#   <!-- header and search box section Start -->
#   <!-- HEADER CODE -->
#   <div class="dice-navbar" role="navigation">
#    <div class="container">
#     <div class="navbar-header">
#      <button class="navbar-toggle nbt" data-target="#menu-toggle" type="button">
#       <span class="sr-only">
#        Toggle navigation
#       </span>
#       <span class="icon-bar">
#       </span>
#       <span class="icon-bar">
#       </span>
#       <span class="icon-bar">
#       </span>
#      </button>
#      <button class="navbar-toggle nbt navbar-magnifier search" data-target="#search-toggle" type="button">
#       <span class="icon icon-magnifier searchspan">
#       </span>
#      </button>
#      <div class="dice-navbar-brand">
#       <a class="logo" href="http://www.dice.com">
#       </a>
#      </div>
#     </div>
#     <div class="collapse navbar-collapse" id="menu-toggle" style="max-height: 100% !important;">
#      <div>
#       <!-- MOBILE -->
#       <ul class="nav navbar-nav ">
#        <li class="dropdown">
#         <a class="dropdown-toggle smartMenu btn-link" data-target="#smart-toggle1" id="smart-toggle-Career">
#          Tech Careers
#          <i class="icon-arrow-68">
#          </i>
#          <i class="icon-arrow-67">
#          </i>
#         </a>
#         <ul class="dropdown-menu dropdown-smartMenu" id="smart-toggle1">
#          <!-- <span class="open"></span> -->
#          <li>
#           <a href="/jobs">
#            Job Search
#           </a>
#          </li>
#          <li>
#           <a href="/skills">
#            Skills Center
#           </a>
#          </li>
#          <li>
#           <a href="https://www.dice.com/mobile">
#            Dice Careers Mobile
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li>
#         <a href="http://insights.dice.com/career-toolkit/">
#          Career Center
#         </a>
#        </li>
#        <li>
#         <a href="http://insights.dice.com/">
#          Insights
#         </a>
#        </li>
#       </ul>
#       <ul class="nav navbar-nav navbar-right visible-xs visible-sm">
#        <li>
#         <a href="http://www.dice.com/products/webstore">
#          Post Jobs
#         </a>
#        </li>
#        <li>
#         <a href="http://www.dice.com/products">
#          Talent Solutions
#         </a>
#        </li>
#        <li>
#         <a class="btn-link" href="/dashboard/login">
#          Login/Register
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div>
#       <!-- DESKTOP -->
#       <ul class="nav navbar-nav navbar-right hidden-xs hidden-sm">
#        <li>
#         <a href="http://www.dice.com/products/webstore">
#          Post Jobs
#         </a>
#        </li>
#        <li>
#         <a href="http://www.dice.com/products">
#          Talent Solutions
#         </a>
#        </li>
#        <li>
#         <a class="btn-link" href="/dashboard/login">
#          Login/Register
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <!--/.nav-collapse -->
#    </div>
#    <!-- END CONTAINER -->
#   </div>
#   <!-- END DICE-NAVBAR -->
#   <!-- END HEADER CODE -->
#   <div class="delaccMsgSec" id="delaccMsgSec">
#    <div class="container">
#     <div class="row">
#      <div class="col-md-9">
#       Your account has successfully been deleted. We're sorry to see you go!
#      </div>
#      <div class="col-md-3">
#       <a class="pull-right" href="#" id="hideDelMsg">
#        Hide this message
#       </a>
#      </div>
#     </div>
#    </div>
#   </div>
#   <!-- For label uncomment these lines and replace dice-float-label-on class with diceFloatLabelOnQ and diceFloatLabelOnL-->
#   <input id="settingDefaulteJobTypes" type="hidden" value="false"/>
#   <input id="defaulteJobTypes" type="hidden" value="Full Time"/>
#   <input id="pcip" type="hidden" value="208.185.23.206"/>
#   <div class="hidden-xs hidden-sm page-header navbar-collapse" id="search-toggle">
#    <div class="container form-horizontal dice-job-search">
#     <form action="https://www.dice.com/jobs" id="searchJob" method="get">
#      <div class="form-group">
#       <div class="col-sm-5 col-md-6 keyword-field dice-float-label dice-float-label-on">
#        <label for="job">
#         job title, skills, keywords or company name
#        </label>
#        <input autocomplete="off" class="form-control input-lg" id="job" maxlength="512" name="q" type="text" value="data science"/>
#        <div class="spacer hidden-lg hidden-md">
#        </div>
#        <span class="inputicon-magnifier icon-magnifier">
#        </span>
#       </div>
#       <div class="col-sm-4 col-md-3 location-field dice-float-label dice-float-label-on">
#        <label for="location">
#         zip code, city or state
#        </label>
#        <input autocomplete="off" class="form-control input-lg" id="location" maxlength="512" name="l" style="padding-right: 0px;" type="text" value="New York, NY"/>
#        <span class="inputicon-compass-3 icon-compass-3">
#        </span>
#        <div class="spacer hidden-lg hidden-md">
#        </div>
#       </div>
#       <div class="col-sm-3 find-jobs-field">
#        <input class="btn btn-lg btn-primary btn-block dice-btn mB5" onclick="getData()" type="button" value="Find Tech Jobs"/>
#        <a class="dice-btn-link" href="https://www.dice.com/jobs/advancedSearch.html">
#         Advanced Search
#        </a>
#       </div>
#       <!-- hide the filter job notification page -->
#       <div class="col-md-6 col-sm-9 col-xs-9 col-lg-6 globalSearchFilterCheck">
#        <span class="chklabel">
#         <input class="typeChkBox" type="checkbox" value="Full Time"/>
#         <a class="hjtype tjth" href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Full-Time
#         </a>
#        </span>
#        <span class="chklabel">
#         <input class="typeChkBox" type="checkbox" value="Part Time"/>
#         <a class="hjtype tjth" href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Part_Time-radius-30-jobs.html" rel="nofollow">
#          Part-Time
#         </a>
#        </span>
#        <span class="chklabel">
#         <input class="typeChkBox" type="checkbox" value="Contracts"/>
#         <a class="hjtype tjth" href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Contracts-radius-30-jobs.html" rel="nofollow">
#          Contracts
#         </a>
#        </span>
#        <span class="chklabel last">
#         <input class="typeChkBox" type="checkbox" value="Third Party"/>
#         <a class="hjtype tjth" href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Third_Party-radius-30-jobs.html" rel="nofollow">
#          Third Party
#         </a>
#         <a class="thirdPartyModal" data-target="#3rdparty" data-toggle="modal">
#          <i class="icon icon-question-mark">
#          </i>
#         </a>
#        </span>
#       </div>
#      </div>
#     </form>
#    </div>
#   </div>
#   <div class="modal fade" id="3rdparty" role="dialog">
#    <div class="modal-dialog">
#     <div class="modal-content">
#      <div class="modal-header">
#       <button aria-hidden="true" class="close" data-dismiss="modal" type="button">
#        ×
#       </button>
#       <h3>
#        What does selecting Third Party mean?
#       </h3>
#       <script src="//">
#       </script>
#       <meta content="what_is_thirdparty_modal" name="ompagename"/>
#       <meta content="tech pro" name="channel"/>
#      </div>
#      <div class="modal-body">
#       <p>
#        Selecting Third Party means you are a recruiter or staffing agency representing a tech professional to apply for Contract Corp-to-Corp and/or Contract-to-Hire Corp-to-Corp jobs.
#       </p>
#       <p>
#        If you are a tech professional who wants to directly apply for jobs, do NOT select Third Party.
#       </p>
#      </div>
#      <div class="modal-footer">
#       <a class="btn btn-primary" data-dismiss="modal" href="#">
#        Close
#       </a>
#      </div>
#     </div>
#     <!--  END MODAL CONTENT  -->
#    </div>
#    <!--  END MODAL DIALOG  -->
#   </div>
#   <!--  END THIRD PARTY MODAL  -->
#   <!-- header and search box section End -->
#   <!-- search result section Start -->
#   <div class="container jobs-container">
#    <div class="row hidden-xs">
#     <div class="col-md-9 col-md-offset-3">
#      <div class="top-ad">
#       <!-- Start: GPT Async -->
#       <script type="text/javascript">
#        var gptadslots=[];
#                         var googletag = googletag || {};
#                         googletag.cmd = googletag.cmd || [];
#                         (function(){ var gads = document.createElement('script');
#                             gads.async = true; gads.type = 'text/javascript';
#                             var useSSL = 'https:' == document.location.protocol;
#                             gads.src = (useSSL ? 'https:' : 'http:') + '//www.googletagservices.com/tag/js/gpt.js';
#                             var node = document.getElementsByTagName('script')[0];
#                             node.parentNode.insertBefore(gads, node);
#                         })();
#       </script>
#       <script type="text/javascript">
#        googletag.cmd.push(function() {
#
#                             //Adslot 1 declaration
#                             gptadslots[1]= googletag.defineSlot('/4140/dice/job_tools', [[728,90]],'div-gpt-ad-136689231299775354-1').addService(googletag.pubads());
#
#                             //Adslot 2 declaration
#                             gptadslots[2]= googletag.defineSlot('/4140/dice/jobsearch', [[160,600]],'div-gpt-ad-136689231299775354-2').addService(googletag.pubads());
#
#                             googletag.pubads().setTargeting('kw',['java']);
#                             googletag.pubads().enableAsyncRendering();
#                             googletag.enableServices();
#                         });
#       </script>
#       <script type="text/javascript">
#        googletag.cmd.push(function() {
#                             googletag.defineSlot('/4140/Dice/job_tools', [728, 90], 'div-gpt-ad-1460157222649-0').addService(googletag.pubads());
#
#                             googletag.defineSlot('/4140/Dice', [160, 320], 'div-gpt-ad-1472586159694-3').addService(googletag.pubads()).setTargeting('kw',['']).setCollapseEmptyDiv(true);
#
#                             googletag.pubads().enableSingleRequest();
#                             googletag.enableServices();
#                         });
#       </script>
#       <!-- End: GPT -->
#       <!-- /4140/Dice/job_tools -->
#       <div id="div-gpt-ad-1460157222649-0" style="height:90px; width:728px;">
#        <script type="text/javascript">
#         googletag.cmd.push(function() { googletag.display('div-gpt-ad-1460157222649-0'); });
#        </script>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="notifications top-right">
#    </div>
#    <div class="row">
#     <!-- search result left section Start -->
#     <!-- hide the filter job notification page -->
#     <div class="col-md-3 hidden-xs hidden-sm" id="filterSec">
#      <!-- search result left section for Recent Searches Start -->
#      <!-- search result left section for Recent Searches End -->
#      <!-- search result left section for Reset and Filter Start -->
#      <div class="page-header-custom" id="resetSec">
#       <div class="row">
#        <div class="col-xs-12">
#         <h2 class="pull-left h2 hidden-xs hidden-sm">
#          <span class="icon-filter-3">
#          </span>
#          Filter Results
#         </h2>
#         <a class="btn dice-btn-active hidden-md hidden-lg" onclick="toggleFilter()">
#          Filter
#         </a>
#         <a class="reset-btn dice-btn-link pull-right hidden-xs hidden-sm" href="#" id="reset-d">
#          Reset
#         </a>
#         <a class="btn dice-btn-secondary pull-right hidden-md hidden-lg" href="#" id="reset-m">
#          Reset
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- search result left section for Reset and Filter End -->
#      <!-- search result left section for Distance, Title, Company, Employment Type and Company Segment Start -->
#      <!-- Company Segment Section Start from here -->
#      <div class="page-header-custom" id="companySegments">
#       <div class="fh">
#        Company Segment
#        <span class="icon-filled-add-1 pull-right">
#        </span>
#       </div>
#       <div class="default" style="display:none;">
#        <div class="filter-option">
#         <input chktyp="dcs" chkval="Recruiter" class="fchk csck" type="checkbox" value="Recruiter"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dcs-Recruiter-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Recruiter
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="dcs" chkval="DirectHire" class="fchk csck" type="checkbox" value="DirectHire"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dcs-DirectHire-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          DirectHire
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- Company Segment Section End from here -->
#      <!-- Radius Section Start from here -->
#      <input id="distanceInMiles" type="hidden" value="true"/>
#      <div class="page-header-custom" id="locationMiles">
#       <div class="fh">
#        Distance
#        <span class="icon-filled-add-1 pull-right">
#        </span>
#       </div>
#       <div class="default" style="display:none;">
#        <div class="filter-option">
#         <input chktyp="radius" chkval="El" class="fchk rchk" type="checkbox"/>
#         Exact Location
#        </div>
#        <div class="filter-option">
#         <input chktyp="radius" chkval="5" class="fchk rchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Full_Time-radius-5-jobs.html" rel="nofollow">
#          Within 5 miles
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="radius" chkval="10" class="fchk rchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Full_Time-radius-10-jobs.html" rel="nofollow">
#          Within 10 miles
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="radius" chkval="20" class="fchk rchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Full_Time-radius-20-jobs.html" rel="nofollow">
#          Within 20 miles
#         </a>
#        </div>
#        <div class="filter-option">
#         <input checked="checked" chktyp="radius" chkval="30" class="fchk sel rchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Within 30 miles
#         </a>
#        </div>
#        <div class="mTB2">
#         <a class="m" href="#" onclick="javascript:displayfullcontent(this);javascript:return false;">
#          more
#         </a>
#        </div>
#       </div>
#       <div class="more disNon">
#        <div class="filter-option">
#         <input chktyp="radius" chkval="40" class="fchk rchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Full_Time-radius-40-jobs.html" rel="nofollow">
#          Within 40 miles
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="radius" chkval="50" class="fchk rchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Full_Time-radius-50-jobs.html" rel="nofollow">
#          Within 50 miles
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="radius" chkval="75" class="fchk rchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Full_Time-radius-75-jobs.html" rel="nofollow">
#          Within 75 miles
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="radius" chkval="100" class="fchk rchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Full_Time-radius-100-jobs.html" rel="nofollow">
#          Within 100 miles
#         </a>
#        </div>
#        <div class="mTB2">
#         <a class="l" href="#" onclick="javascript:displayfullcontent(this);javascript:return false;">
#          less
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- Radius Section End from here -->
#      <!-- Position Title Section Start from here -->
#      <div class="page-header-custom" id="positionTitle">
#       <div class="fh">
#        Title
#        <span class="icon-filled-add-1 pull-right">
#        </span>
#       </div>
#       <div class="default" style="display:none;">
#        <div class="filter-option">
#         <input chktyp="djt" chkval="Software+Development+Engineer" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-djt-Software_Development_Engineer-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Software Development Engineer
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="djt" chkval="Network+Engineer" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-djt-Network_Engineer-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Network Engineer
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="djt" chkval="Java+Developer" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-djt-Java_Developer-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Java Developer
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="djt" chkval="Business+Analyst" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-djt-Business_Analyst-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Business Analyst
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="djt" chkval="Software+Engineer" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-djt-Software_Engineer-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Software Engineer
#         </a>
#        </div>
#        <div class="mTB2">
#         <a class="m" href="#" onclick="javascript:displayfullcontent(this);javascript:return false;">
#          more
#         </a>
#        </div>
#       </div>
#       <div class="more disNon">
#        <div class="filter-option">
#         <input chktyp="djt" chkval="Data+Scientist" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-djt-Data_Scientist-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Data Scientist
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="djt" chkval="Senior+Java+Developer" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-djt-Senior_Java_Developer-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Senior Java Developer
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="djt" chkval="C%2B%2B+Developer" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-djt-C%2B%2B_Developer-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          C++ Developer
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="djt" chkval="Full+Stack+Developer" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-djt-Full_Stack_Developer-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Full Stack Developer
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="djt" chkval="Data+Analyst" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-djt-Data_Analyst-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Data Analyst
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="djt" chkval="Software+Development+Manager" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-djt-Software_Development_Manager-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Software Development Manager
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="djt" chkval="DevOps+Engineer" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-djt-DevOps_Engineer-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          DevOps Engineer
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="djt" chkval="Network+Administrator" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-djt-Network_Administrator-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Network Administrator
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="djt" chkval="Principal+%26%2345+Business+Consulting" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-djt-Principal_%26%2345_Business_Consulting-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Principal - Business Consultin
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="djt" chkval="SQL+Developer" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-djt-SQL_Developer-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          SQL Developer
#         </a>
#        </div>
#        <div class="mTB2">
#         <a class="l" href="#" onclick="javascript:displayfullcontent(this);javascript:return false;">
#          less
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- Position Title Section End from here -->
#      <!-- Location Section Start from here -->
#      <div class="page-header-custom" id="locations">
#       <div class="fh">
#        Location
#        <span class="icon-filled-add-1 pull-right">
#        </span>
#       </div>
#       <div class="default" style="display:none;">
#        <div class="filter-option">
#         <input checked="checked" chktyp="l" chkval="New York, NY" class="fchk sel" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          New York, NY
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="l" chkval="Jersey City, NJ" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-Jersey_City%2C_NJ-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Jersey City, NJ
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="l" chkval="New York City, NY" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York_City%2C_NY-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          New York City, NY
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="l" chkval="Newark, NJ" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-Newark%2C_NJ-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Newark, NJ
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="l" chkval="Parsippany, NJ" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-Parsippany%2C_NJ-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Parsippany, NJ
#         </a>
#        </div>
#        <div class="mTB2">
#         <a class="m" href="#" onclick="javascript:displayfullcontent(this);javascript:return false;">
#          more
#         </a>
#        </div>
#       </div>
#       <div class="more disNon">
#        <div class="filter-option">
#         <input chktyp="l" chkval="Edison, NJ" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-Edison%2C_NJ-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Edison, NJ
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="l" chkval="Nyc, NY" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-Nyc%2C_NY-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Nyc, NY
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="l" chkval="Brooklyn, NY" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-Brooklyn%2C_NY-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Brooklyn, NY
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="l" chkval="Manhattan, NY" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-Manhattan%2C_NY-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Manhattan, NY
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="l" chkval="Warren, NJ" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-Warren%2C_NJ-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Warren, NJ
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="l" chkval="Greenwich, CT" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-Greenwich%2C_CT-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Greenwich, CT
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="l" chkval="Piscataway, NJ" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-Piscataway%2C_NJ-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Piscataway, NJ
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="l" chkval="White Plains, NY" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-White_Plains%2C_NY-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          White Plains, NY
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="l" chkval="Rockleigh, NJ" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-Rockleigh%2C_NJ-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Rockleigh, NJ
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="l" chkval="Yonkers, NY" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-Yonkers%2C_NY-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Yonkers, NY
#         </a>
#        </div>
#        <div class="mTB2">
#         <a class="l" href="#" onclick="javascript:displayfullcontent(this);javascript:return false;">
#          less
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- Location Title Section End from here -->
#      <!-- Company Section Start from here -->
#      <div class="page-header-custom" id="companies">
#       <div class="fh">
#        Company
#        <span class="icon-filled-add-1 pull-right">
#        </span>
#       </div>
#       <div class="default" style="display:none;">
#        <div class="filter-option">
#         <input chktyp="dc" chkval="CyberCoders" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dc-CyberCoders-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          CyberCoders
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="dc" chkval="Amazon" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dc-Amazon-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Amazon
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="dc" chkval="Deloitte" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dc-Deloitte-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Deloitte
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="dc" chkval="Gambit+Technologies" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dc-Gambit_Technologies-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Gambit Technologies
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="dc" chkval="Robert+Half+Technology" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dc-Robert_Half_Technology-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Robert Half Technology
#         </a>
#        </div>
#        <div class="mTB2">
#         <a class="m" href="#" onclick="javascript:displayfullcontent(this);javascript:return false;">
#          more
#         </a>
#        </div>
#       </div>
#       <div class="more disNon">
#        <div class="filter-option">
#         <input chktyp="dc" chkval="Bebee+Affinity+Social+Network" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dc-Bebee_Affinity_Social_Network-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Bebee Affinity Social Network
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="dc" chkval="Bloomberg+L.P." class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dc-Bloomberg_L.P.-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Bloomberg L.P.
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="dc" chkval="Mitchell+Martin" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dc-Mitchell_Martin-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Mitchell Martin
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="dc" chkval="Software+Guidance+%26+Assistance" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dc-Software_Guidance_%26_Assistance-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Software Guidance &amp; Assistance
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="dc" chkval="Princeton+Information+Ltd" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dc-Princeton_Information_Ltd-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Princeton Information Ltd
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="dc" chkval="Crestron+Electronics+Inc" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dc-Crestron_Electronics_Inc-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Crestron Electronics Inc
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="dc" chkval="Kforce+Inc." class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dc-Kforce_Inc.-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Kforce Inc.
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="dc" chkval="Mitchell+Martin%2C+Inc." class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dc-Mitchell_Martin%2C_Inc.-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Mitchell Martin, Inc.
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="dc" chkval="MUFG" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dc-MUFG-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          MUFG
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="dc" chkval="Andiamo+Partners" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dc-Andiamo_Partners-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Andiamo Partners
#         </a>
#        </div>
#        <div class="mTB2">
#         <a class="l" href="#" onclick="javascript:displayfullcontent(this);javascript:return false;">
#          less
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- Company Section End from here -->
#      <!-- EMPLOYMENT_TYPE Section Start from here -->
#      <div class="page-header-custom" id="jobTypes">
#       <div class="fh">
#        Employment Type
#        <span class="icon-filled-add-1 pull-right">
#        </span>
#       </div>
#       <div class="default" style="display:none;">
#        <div class="filter-option">
#         <input checked="checked" chktyp="jtype" chkval="Full+Time" class="fchk sel" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Full-Time
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="jtype" chkval="Part+Time" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Part_Time-radius-30-jobs.html" rel="nofollow">
#          Part-Time
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="jtype" chkval="Contracts" class="cfchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Contracts-radius-30-jobs.html" rel="nofollow">
#          Contracts
#         </a>
#        </div>
#       </div>
#       <div class="more disNon mL20 Contracts">
#        <div class="filter-option">
#         <input chktyp="jtype" chkval="Contract+Independent" class="fchk cjtype" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Contract_Independent-radius-30-jobs.html" rel="nofollow">
#          Contract Independent
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="jtype" chkval="Contract+W2" class="fchk cjtype" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Contract_W2-radius-30-jobs.html" rel="nofollow">
#          Contract W2
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="jtype" chkval="C2H+Independent" class="fchk cjtype" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-C2H_Independent-radius-30-jobs.html" rel="nofollow">
#          C2H Independent
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="jtype" chkval="C2H+W2" class="fchk cjtype" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-C2H_W2-radius-30-jobs.html" rel="nofollow">
#          C2H W2
#         </a>
#        </div>
#       </div>
#       <div class="default" style="display:none;">
#        <div class="filter-option">
#         <input chktyp="jtype" chkval="Third+Party" class="cfchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Third_Party-radius-30-jobs.html" rel="nofollow">
#          Third Party
#         </a>
#         <a class="thirdPartyModal" data-target="#3rdparty" data-toggle="modal">
#          <i class="icon icon-question-mark">
#          </i>
#         </a>
#        </div>
#       </div>
#       <div class="more disNon mL20 Party">
#        <div class="filter-option">
#         <input chktyp="jtype" chkval="Contract+Corp%26%2345To%26%2345Corp" class="fchk cjtype" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Contract_Corp%26%2345To%26%2345Corp-radius-30-jobs.html" rel="nofollow">
#          Contract Corp-To-Corp
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="jtype" chkval="C2H+Corp%26%2345To%26%2345Corp" class="fchk cjtype" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-C2H_Corp%26%2345To%26%2345Corp-radius-30-jobs.html" rel="nofollow">
#          C2H Corp-To-Corp
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- EMPLOYMENT_TYPE Section End from here -->
#      <!-- Telecommute Option Start from here -->
#      <div class="page-header-custom" id="telecommuteOption">
#       <div class="fh">
#        Telecommute
#        <span class="icon-filled-add-1 pull-right">
#        </span>
#       </div>
#       <div class="default" style="display:none;">
#        <div class="filter-option">
#         <input chktyp="dtco" chkval="true" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dtco-true-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Yes
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- Telecommute Option End from here -->
#      <!-- search result left section for Distance, Title, Company, Employment Type and Company Segment End -->
#     </div>
#     <div class="col-md-9" id="resultSec">
#      <!-- search result section left End -->
#      <!-- search result section right Start -->
#      <!-- <div class="col-md-9" id="resultSec">  -->
#      <div class="jobs-page-header">
#       <!-- search result section right Header Start -->
#       <div class="row hidden-xs hidden-sm">
#        <div class="col-md-9">
#         <h1 class="pull-left h1 jobs-page-header-h1">
#          Full-Time data science jobs in New York, NY
#         </h1>
#        </div>
#        <div class="col-md-3">
#         <!-- Replacing for job notification page -->
#         <a class="btn btn-lg dice-btn-secondary job-alert pull-right" data-target="#myModal" data-toggle="modal">
#          <span class="icon-mail-1">
#          </span>
#          Create Job Alert
#         </a>
#        </div>
#       </div>
#       <div class="row visible-xs visible-sm">
#        <div class="col-md-12">
#         <h2 class="h1 jobs-page-header-h1">
#          Full-Time data science jobs in New York, NY
#         </h2>
#        </div>
#       </div>
#       <div class="row visible-xs visible-sm">
#        <div class="col-md-12 col-lg-12">
#         <h4 class="pull-left posiCount sort mobile">
#          <span>
#           1 - 30
#          </span>
#          of
#          <span>
#           2963
#          </span>
#          positions
#         </h4>
#        </div>
#       </div>
#       <div class="row visible-xs visible-sm hidden-md hidden-lg mobile-btns">
#        <div class="col-md-12">
#         <a class="btn dice-btn-secondary" onclick="toggleFilter()">
#          <span class="icon-filter-3">
#          </span>
#          Filter
#         </a>
#         <!-- Replacing for job notification page -->
#         <a class="btn dice-btn-secondary job-alert pull-right" data-target="#myModal" data-toggle="modal">
#          <span class="icon-mail-1">
#          </span>
#          Create Job Alert
#         </a>
#        </div>
#       </div>
#       <div class="row hidden-xs hidden-sm">
#        <div class="col-md-12 col-lg-12">
#         <h4 class="pull-left posiCount sort">
#          <span>
#           1 - 30
#          </span>
#          of
#          <span>
#           2963
#          </span>
#          positions
#         </h4>
#        </div>
#       </div>
#       <div class="row">
#        <div class="col-md-12 col-lg-12">
#         <hr/>
#        </div>
#        <div class="hidden-xs hidden-sm col-md-6 col-lg-6 mT10">
#         <div id="dice_paging_top">
#         </div>
#        </div>
#        <div class="col-sm-3 col-xs-3 col-md-2 col-lg-3 mT10">
#        </div>
#        <div class="col-xs-9 col-sm-9 col-md-3 col-lg-3 mT10 mB5">
#         <h4 class="sort" style="font-size:13px;">
#          <span class="hidden-xs hidden-sm">
#           Sort by:
#          </span>
#          <span id="sortby">
#           <span>
#            relevance
#           </span>
#           |
#           <a class="dice-btn-link" href="#" id="sort-by-date-link" rel="nofollow">
#            date
#           </a>
#           <span id="distancepipe" style="display:none">
#            |
#           </span>
#           <a class="dice-btn-link" href="#" id="sort-by-distance-link" rel="nofollow" style="display:none">
#            distance
#           </a>
#          </span>
#         </h4>
#        </div>
#       </div>
#       <!-- search result section right Header End -->
#      </div>
#      <div class="row" id="search-results-control">
#       <div class="col-md-9">
#        <!-- search result section right Content Block  Start  -->
#        <div id="serp">
#         <!-- starting Div for viewed Job -->
#         <div class="complete-serp-result-div" id="viewedIde0788f7f50d315de25ee1d91fe85d44a">
#          <div class="serp-result-content">
#           <input id="featureIde0788f7f50d315de25ee1d91fe85d44a" type="hidden" value="false"/>
#           <div class="logo-section hidden-xs">
#            <div class="logopath">
#             <a class="circle" href="https://www.dice.com/company/amazon20" style="display:none;">
#              A
#             </a>
#             <a href="https://www.dice.com/company/amazon20">
#              <img alt="Amazon" onerror="errorImg(this)" src="//assets.dice.com/external/images/empLogos/2b1e93fe4d46ef6752eb8c1b080d6c1d.jpg"/>
#             </a>
#            </div>
#           </div>
#           <h3>
#            <a class="dice-btn-link" href="https://www.dice.com/jobs/detail/Software-Development-Engineer%2C-Data-Science-Amazon-Newark-NJ-07101/amazon20/446982?icid=sr1-1p&amp;q=data science&amp;l=New York, NY" id="position0" onclick="cookieJobID('e0788f7f50d315de25ee1d91fe85d44a');setCookieViewedJobs('e0788f7f50d315de25ee1d91fe85d44a');" title="Software Development Engineer, Data Science" value="e0788f7f50d315de25ee1d91fe85d44a">
#             Software Development Engineer, Data Science
#             <span class="job-status-indicator icon-preview-1 visited ">
#             </span>
#             <span class="job-status-indicator icon-star-1 saveaction" id="e0788f7f50d315de25ee1d91fe85d44a" issavedjob="false">
#             </span>
#            </a>
#           </h3>
#           <div class="shortdesc">
#            Audible, Inc. is the world's largest seller and producer of downloadable audiobooks, a curator of short-form audio...
#           </div>
#           <ul class="list-inline details row">
# ...
#          </span>
#         </div>
#        </div>
#        <div class="form-group">
#         <div class="col-md-8">
#          <p class="pull-right">
#           <a href="http://www.dice.com/profman/resetPassword.jsp" target="_blank">
#            Forgot Password?
#           </a>
#          </p>
#         </div>
#        </div>
#       </form>
#      </div>
#      <div class="modal-footer footr" style="margin-top: 0;">
#       <div class="row">
#        <!-- <div class="col-sm-4"><p class=""><a href="http://www.dice.com/profman/resetPassword.jsp" target="_blank">Forgot Password?</a></p></div> -->
#        <div class="col-md-2">
#         <button class="btn btn-primary btn-lg" id="signBtnId" onclick="loginSubmit();" style="background-color: #006699" type="button">
#          Sign In
#         </button>
#        </div>
#        <div class="col-md-1">
#         <span id="loginLoaderImg" style="display: none; line-height: 38px;">
#          <img alt="Loading" src="//assets.dice.com/techpro/img/loading24px.gif"/>
#         </span>
#        </div>
#        <div class="col-md-2" id="skipBtn">
#        </div>
#        <div class="col-md-7">
#         <span class="pull-right" style="line-height: 38px;">
#          Don't have an account?
#          <a href="/register" id="register" onclick="return redirectURLCookie();" target="_parent">
#           Register
#          </a>
#         </span>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div aria-hidden="true" aria-labelledby="myModalLabel" class="modal fade" id="myModal" role="dialog" tabindex="-1">
#    <div class="modal-dialog">
#     <div class="modal-content">
#      <div class="modal-header">
#       <button aria-hidden="true" class="close" data-dismiss="modal" type="button">
#        ×
#       </button>
#       <h3 class="modal-title" id="myModalLabel">
#        Create an alert
#       </h3>
#      </div>
#      <div class="modal-body alert_body">
#       <form class="form-horizontal" id="CreateAlertForm_1" name="jobAlert">
#        <div class="form-group">
#         <div class="col-sm-2">
#          <label class="control-label">
#           Title
#          </label>
#         </div>
#         <div class="col-sm-10">
#          <input class="form-control" id="alertname" maxlength="100" name="name" placeholder="Enter a title" type="text" value="data science"/>
#          <div class="help-block hidden validTitle">
#           Please enter a title.
#          </div>
#         </div>
#        </div>
#        <div class="form-group" style="margin-bottom: 0px;">
#         <div class="col-sm-2">
#          <label class="control-label" for="">
#           Email
#          </label>
#         </div>
#         <div class="col-sm-10">
#          <input class="form-control" id="alertEmail" name="email" placeholder="Enter an email" type="text" value=""/>
#          <input class="form-control hidden" id="alertDisabled" name="disabled" type="text" value="false"/>
#          <input class="form-control hidden" id="emailFrequency" name="emailFrequency" type="text" value="never"/>
#          <div class="help-block hidden validEmail">
#           Please enter a valid email (email@domain.com).
#          </div>
#         </div>
#        </div>
#       </form>
#      </div>
#      <div class="modal-footer alert_footer">
#       <div class="row">
#        <div class="col-md-12">
#         <button class="btn btn-primary" onclick="crateJobAlter()" style="background:#006699;" type="button">
#          Create Alert
#         </button>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script src="//ajax.googleapis.com/ajax/libs/jquery/1.12.0/jquery.min.js">
#   </script>
#   <script type="text/javascript">
#    var diceJSON = {page : 1, pageCount : 99 , limit : 30} ;
# 		function errorImg(obj) {
# 			$(obj).hide();
# 			$(obj).parent().siblings('.circle').show();
# 		}
#   </script>
#   <script>
#    _satellite.pageBottom()
#   </script>
#   <script>
#    $.get("https://www.dice.com/refresh/seeker");
#   </script>
#   <script>
#    $.get("https://www.dice.com/refresh/DGL");
#   </script>
#   <!-- <script type="text/javascript" src="//maps.googleapis.com/maps/api/js?sensor=true&libraries=places&v=3.22"></script> -->
#   <script src="//maps.googleapis.com/maps/api/js?libraries=places&amp;v=3.23&amp;key=AIzaSyBIdPte3BjiTJYhsuLfzBJgUAHGQx_l07U" type="text/javascript">
#   </script>
#   <script src="//assets.dice.com/techpro/js/global/login-dialog.js">
#   </script>
#   <script src="https://apis.google.com/js/api:client.js">
#   </script>
#   <script type="text/javascript">
#    $(document).ready(footercollapse);
# $(window).resize(footercollapse);
#
# function footercollapse() {
# 	//deleteCookie('DJV_UNREGISTERED', '/');
# 	if ((window.innerWidth || document.body.offsetWidth) < 992) {
# 		$('#dice-sites').removeClass('in').addClass('collapse');
# 		$('#dice-services').removeClass('in').addClass('collapse');
# 		$('#learn-about-dice').removeClass('in').addClass('collapse');
# 	} else {
# 		$('#dice-sites').addClass('in').removeClass('collapse').removeAttr('style');
# 		$('#dice-services').addClass('in').removeClass('collapse').removeAttr('style');
# 		$('#learn-about-dice').addClass('in').removeClass('collapse').removeAttr('style');
# 	}
# }
#   </script>
#   <script>
#    // Include the UserVoice JavaScript SDK (only needed once on a page)
# UserVoice=window.UserVoice||[];(function(){var uv=document.createElement('script');uv.type='text/javascript';uv.async=true;uv.src='//widget.uservoice.com/xNTaf4xWM431ZBy72jhpyw.js';var s=document.getElementsByTagName('script')[0];s.parentNode.insertBefore(uv,s)})();
#
# //
# // UserVoice Javascript SDK developer documentation:
# // https://www.uservoice.com/o/javascript-sdk
# //
#
# // Set colors
# UserVoice.push(['set', {
#   accent_color: '#66cc66',
#   trigger_color: 'white',
#   trigger_background_color: '#66cc66'
# }]);
#
# // Identify the user and pass traits
# // To enable, replace sample data with actual user traits and uncomment the line
# UserVoice.push(['identify', {
#   //email:      'john.doe@example.com', // Users email address
#   //name:       'John Doe', // Users real name
#   //created_at: 1364406966, // Unix timestamp for the date the user signed up
#   //id:         123, // Optional: Unique id of the user (if set, this should not change)
#   //type:       'Owner', // Optional: segment your users by type
#   //account: {
#   //  id:           123, // Optional: associate multiple users with a single account
#   //  name:         'Acme, Co.', // Account name
#   //  created_at:   1364406966, // Unix timestamp for the date the account was created
#   //  monthly_rate: 9.99, // Decimal; monthly rate of the account
#   //  ltv:          1495.00, // Decimal; lifetime value of the account
#   //  plan:         'Enhanced' // Plan name for the account
#   //}
# }]);
#
# // Add default trigger to the bottom-right corner of the window:
# UserVoice.push(['addTrigger', { mode: 'contact', trigger_position: 'center-right' }]);
#
# // Or, use your own custom trigger:
# //UserVoice.push(['addTrigger', '#id', { mode: 'contact' }]);
#
# // Autoprompt for Satisfaction and SmartVote (only displayed under certain conditions)
# UserVoice.push(['autoprompt', {}]);
#   </script>
#   <script type="text/javascript">
#    $('.nbt').unbind('click');
# 	$('.nbt').click(function(){
# 		var navbars = $('.navbar-collapse');
# 		var navtoggle = $(this).attr('data-target');
#
# 		for(var i=0; i< navbars.length;i++){
# 			if(navtoggle != '#'+ $(navbars[i]).attr('id')
# 				&& $(navbars[i]).hasClass('slideUp')){
# 				$(navbars[i]).slideUp();
# 				$(navbars[i]).removeClass('slideUp');
# 			}
# 		}
#
# 		if($(navtoggle).length > 0){
# 			if($(navtoggle).hasClass('hidden-xs')){
# 				$(navtoggle).removeClass('hidden-xs hidden-sm');
# 				$(navtoggle).css('display','none');
# 			}
#
# 			if($(navtoggle).hasClass('slideUp')){
# 				$(navtoggle).slideUp();
# 				$(navtoggle).removeClass('slideUp');
# 			}
# 			else{
# 				$(navtoggle).slideDown();
# 				$(navtoggle).addClass('slideUp');
# 			}
# 		}
# 		else{
# 			window.location.href = '/jobs';
# 		}
# 	});
#
# 	$('.smartMenu').unbind('click');
# 	$('.smartMenu').click(function(){
# 		var navtoggle = $(this).attr('data-target');
# 		var peopleId = $('#pid').val(), isNotificarion = false;;
# 		var searchableProfile = getCookie('searchableProfileId');
# 		if (this.id === 'smart-notification-toggle-link' || this.id === 'msmart-notification-toggle-link'){
# 			if (peopleId !== undefined || peopleId !== "" || peopleId !== null) {
# 				var notificationCookie = getCookie('notificationViewed'+peopleId);
# 				if (notificationCookie === null || notificationCookie === "" || notificationCookie === "null" || notificationCookie === undefined) {
# 					generateCookie('notificationViewed' + peopleId , false, 24 * 60 * 60 *1, '/');
# 				}
# 			}
# 			hideNotification();
# 			setNotification(this);
# 			isNotificarion = true;
# 		}
# 		if (!isNotificarion) {
# 			navToggleWin(this);
# 		}
# 	});
#
# 	function navToggleWin(obj) {
# 		var navtoggle = $(obj).attr('data-target');
# 		$(obj).find('.icon-arrow-67').hide();
# 		$(obj).find('.icon-arrow-68').hide();
# 		if($(navtoggle).length > 0){
# 			if($(navtoggle).hasClass('slideUp')){
# 				$(obj).find('.icon-arrow-67').show();
# 				$(navtoggle).slideUp(200);
# 				$(navtoggle).removeClass('slideUp');
# 			}
# 			else{
# 				$(obj).find('.icon-arrow-68').show();
# 				$(navtoggle).slideDown(200);
# 				$(navtoggle).addClass('slideUp');
# 			}
# 		}
# 	}
#
# 	//$(document).click(function(e) {
# 	$(document).on('click touchstart', 'html', function(e) {
# 		var target = (e && e.target) || (event && event.srcElement);
# 		if(isPopupClose(target)){
# 			$('.smartMenu').find('.icon-arrow-68').hide();
# 			$('.smartMenu').find('.icon-arrow-67').show();
# 			$('#smart-toggle').slideUp(200);
# 			$('#smart-toggle').removeClass('slideUp');
# 			$('#smart-notification').slideUp(200);
# 			$('#smart-notification').removeClass('slideUp');
# 			$('#msmart-notification').slideUp(200);
# 			$('#msmart-notification').removeClass('slideUp');
# 			$('#smart-toggle1').slideUp(200);
# 			$('#smart-toggle1').removeClass('slideUp');
# 		}
# 	});
#
# 	function isPopupClose(currentTarget) {
# 		var isClose = true, current_element = currentTarget,
# 			smartToggle = document.getElementById('smart-toggle'),
# 			smartToggleLink = document.getElementById('smart-toggle-link'),
# 			smartToggleCareer = document.getElementById('smart-toggle-Career'),
# 			smartNotificationToggleLink = document.getElementById('smart-notification-toggle-link'),
# 			msmartNotificationToggleLink = document.getElementById('msmart-notification-toggle-link');
#
# 		while(current_element && current_element != document.body) {
# 			if (current_element === smartToggle
# 			        || current_element === smartToggleLink
# 			        || current_element === smartToggleCareer
# 			        || current_element === smartNotificationToggleLink
# 			        || current_element === msmartNotificationToggleLink) {
# 				isClose = false;
# 				break;
# 			}
# 			current_element = current_element.parentNode;
# 		}
# 		return isClose;
# 	}
#
# 	function updateSession(updateVal) {
# 		var regExEmail = /^([a-zA-Z0-9_\-\.]+)@([a-zA-Z0-9_\-\.]+)\.([a-zA-Z]{2,5})$/;
# 		var diceCustomerName = $('#dice-customer-name').text();
# 		if(regExEmail.test(diceCustomerName) == true || diceCustomerName == "") {
# 			$.get("https://www.dice.com/refresh/session/"+updateVal+"/");
# 			$('#dice-customer-name').html(updateVal);
# 		}
# 	}
#
# 	hideNotification();
# 	var peopleId = $('#pid').val();
# 	var notificationViewed = getCookie('notificationViewed' + peopleId);
# 	function hideNotification() {
# 		notificationViewed = getCookie('notificationViewed' + peopleId);
# 		if (notificationViewed && notificationViewed != "false") {
# 			$('.notification-bubble').hide();
# 		}
# 	}
# 	setNotification();
# 	function setNotification(navtoggle) {
#         var nc = 0;
#         var searchableProfileId = getCookie('searchableProfileId');
# 		var profilecount = getCookie('profileCount');
# 		$('.notification-bubble').hide();
# 		if (searchableProfileId != null && searchableProfileId && nc === 0) { // searchable profile
# 			$.ajax({
# 				url: '/dashboard/notification/updateNotificationCount?id='+ searchableProfileId,
# 				async: false
# 			}).done(function(data) {
# 				nc = isNaN(data) ? 0 : parseInt(data);}).fail(function(xhr)  {
# 				nc  = 1;
# 			});
# 		}
# 		var marketValueCookie = null;
# 		var peopleId = getCookie('peopleId');
# 		try {
# 			marketValueCookie = getCookie('marketValueCookie'+peopleId);
# 			if(marketValueCookie == null){
# 				// incase cookie is not present assume that we have to show the notification
# 				marketValueCookie = "true";
# 			}
# 		} catch (ignore) {console.log(ignore);}
#
# 		if (searchableProfileId != null && searchableProfileId) { // searchable profile
# 			/* $.get('/dashboard/notification/updateNotificationCount?id='
# 				+ searchableProfileId, function(data, status) { */
# 				var bubbleCount = 1;
# 				if (marketValueCookie === "true") {
# 					bubbleCount = nc + 1;
# 				} else {
# 					$('.marketValue_notification').hide();
# 					bubbleCount = nc;
# 				}
# 				hideNotiMessages(nc, bubbleCount);
# 				if (nc != 0 && (notificationViewed === "false" || notificationViewed === null)) { //has some notification
# 					$('.notification-bubble').show();
# 					$('.notifi_skillopen').show();
# 				} else if (nc != 0) {
# 					$('.notifi_skillopen').show();
# 					$('.notification-bubble').hide();
# 				} else if (bubbleCount == 1) {
# 					$('.notification-bubble').show();
# 				} else { //no notification
# 					$('.notification-bubble').hide();
# 					$('.notifi_nonotification').show();
# 				}
# 				$('.smart-notification').show();
# 				if (navtoggle) {
# 					navToggleWin(navtoggle);
# 				}
# 			//});
# 		} else { //non-searchable or no profile
# 			var countVal = 1;
# 			if (marketValueCookie === "true" && (profilecount != null && profilecount != 0)) {
# 				countVal = parseInt(countVal) + 1;
# 			} else {
# 				$('.marketValue_notification').hide();
# 			}
# 			hideNotiMessages(0, countVal);
# 			$('.notification-bubble').show();
# 			if (profilecount != null && profilecount != 0) { // profile exists but not searchable
# 				if (searchableProfileId != null && searchableProfileId) {
# 					$('.notifi_nonotification').show();
# 				} else {
# 					$('.notifi_makeprofile').show();
# 				}
# 			} else { //profile not exists
# 				$('.notifi_createprofile').show();
# 			}
# 			$('.smart-notification').show();
# 			if (navtoggle) {
# 				navToggleWin(navtoggle);
# 			}
# 		}
# 	}
#
# 	function hideNotiMessages(count, bubbleCount) {
# 		$('.notificationCount').html(count);
# 		$('.bubbleCount').html(bubbleCount);
# 		$('.notifi_skillopen').hide();
# 		$('.notifi_createprofile').hide();
# 		$('.notifi_makeprofile').hide();
# 		$('.notifi_nonotification').hide();
# 	}
#   </script>
#   <script type="text/javascript">
#    /*$(document).ready(function(){
#     $("#welcome-modal").modal();
#   });
#   var date = new Date();
#   date.setTime(date.getTime()+(72*60*60*1000));
#   var expdate = "; expires="+date.toGMTString();
#   document.cookie = "wc_md=" + "1" + expdate + "; path=/";*/
#   </script>
#   <!-- WELCOME MODAL MARKUP -->
#   <div class="modal fade" id="welcome-modal">
#    <div class="modal-dialog">
#     <div class="modal-content">
#      <div class="modal-header">
#       <button aria-hidden="true" class="close" data-dismiss="modal" type="button">
#        ×
#       </button>
#      </div>
#      <div class="modal-body">
#       <p>
#        It's a little rough around the edges. If you find things we could do better, let us know at
#        <a href="mailto:newdicesupport@dice.com">
#         newdicesupport@dice.com
#        </a>
#        or give us a call at 888-321-DICE (3423)
#       </p>
#       <!--<button class="btn btn-default">Return to old Dice</button>-->
#       <button aria-hidden="true" class="btn btn-primary pull-right" data-dismiss="modal">
#        Continue with the new site
#       </button>
#       <div class="clearfix">
#       </div>
#      </div>
#     </div>
#     <!--  END MODAL CONTENT  -->
#    </div>
#    <!--  END MODAL DIALOG  -->
#   </div>
#   <!--  END THIRD PARTY MODAL  -->
#   <!-- END WELCOME MODAL MARKUP -->
#   <script src="//assets.dice.com/techpro/js/global/jobResults.min.js">
#   </script>
#   <script src="//cdn.jsdelivr.net/bootstrap.paginator/0.6.0/bootstrap-paginator.min.js">
#   </script>
#   <script src="//assets.dice.com/techpro/js/global/Chart.min.js">
#   </script>
#   <!-- footer section End -->
#  </body>
# </html>

# %%
from IPython.display import Image
Image('http://www.openbookproject.net/tutorials/getdown/css/images/lesson4/HTMLDOMTree.png')

# %%
#find all the tags in our soup.
for tag in soup.find('h3'):
    print(tag.name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-59a8f3b858f6> in <module>()
#       1 #find all the tags in our soup.
# ----> 2 for tag in soup.find('h3'):
#       3     print(tag.name)
#
# NameError: name 'soup' is not defined

# %%
for links in soup.find_all('a'):
    print (links.get('href'))
# Out:
# http://www.dice.com
# None
# /jobs
# /skills
# https://www.dice.com/mobile
# http://insights.dice.com/career-toolkit/
# http://insights.dice.com/
# http://www.dice.com/products/webstore
# http://www.dice.com/products
# /dashboard/login
# http://www.dice.com/products/webstore
# http://www.dice.com/products
# /dashboard/login
# #
# https://www.dice.com/jobs/advancedSearch.html
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Full_Time-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Part_Time-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Contracts-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Third_Party-radius-30-jobs.html
# None
# #
# None
# #
# #
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dcs-Recruiter-jtype-Full_Time-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dcs-DirectHire-jtype-Full_Time-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Full_Time-radius-5-jobs.html
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Full_Time-radius-10-jobs.html
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Full_Time-radius-20-jobs.html
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Full_Time-radius-30-jobs.html
# #
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Full_Time-radius-40-jobs.html
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Full_Time-radius-50-jobs.html
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Full_Time-radius-75-jobs.html
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Full_Time-radius-100-jobs.html
# #
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-djt-Software_Development_Engineer-jtype-Full_Time-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-djt-Network_Engineer-jtype-Full_Time-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-djt-Java_Developer-jtype-Full_Time-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-djt-Business_Analyst-jtype-Full_Time-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-djt-Software_Engineer-jtype-Full_Time-radius-30-jobs.html
# #
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-djt-Data_Scientist-jtype-Full_Time-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-djt-Senior_Java_Developer-jtype-Full_Time-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-djt-Full_Stack_Developer-jtype-Full_Time-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-djt-C%2B%2B_Developer-jtype-Full_Time-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-djt-Data_Analyst-jtype-Full_Time-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-djt-Software_Development_Manager-jtype-Full_Time-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-djt-DevOps_Engineer-jtype-Full_Time-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-djt-Network_Administrator-jtype-Full_Time-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-djt-SQL_Developer-jtype-Full_Time-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-djt-Senior_iOS_Engineer-jtype-Full_Time-radius-30-jobs.html
# #
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Full_Time-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-Jersey_City%2C_NJ-jtype-Full_Time-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-New_York_City%2C_NY-jtype-Full_Time-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-Newark%2C_NJ-jtype-Full_Time-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-Parsippany%2C_NJ-jtype-Full_Time-radius-30-jobs.html
# #
# https://www.dice.com/jobs/q-data_science-l-Edison%2C_NJ-jtype-Full_Time-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-Nyc%2C_NY-jtype-Full_Time-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-Brooklyn%2C_NY-jtype-Full_Time-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-Manhattan%2C_NY-jtype-Full_Time-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-Warren%2C_NJ-jtype-Full_Time-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-Greenwich%2C_CT-jtype-Full_Time-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-Piscataway%2C_NJ-jtype-Full_Time-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-White_Plains%2C_NY-jtype-Full_Time-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-Rockleigh%2C_NJ-jtype-Full_Time-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-Yonkers%2C_NY-jtype-Full_Time-radius-30-jobs.html
# #
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dc-CyberCoders-jtype-Full_Time-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dc-Amazon-jtype-Full_Time-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dc-Deloitte-jtype-Full_Time-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dc-Gambit_Technologies-jtype-Full_Time-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dc-Robert_Half_Technology-jtype-Full_Time-radius-30-jobs.html
# #
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dc-Bebee_Affinity_Social_Network-jtype-Full_Time-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dc-Bloomberg_L.P.-jtype-Full_Time-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dc-Mitchell_Martin-jtype-Full_Time-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dc-Software_Guidance_%26_Assistance-jtype-Full_Time-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dc-Princeton_Information_Ltd-jtype-Full_Time-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dc-Crestron_Electronics_Inc-jtype-Full_Time-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dc-Kforce_Inc.-jtype-Full_Time-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dc-Mitchell_Martin%2C_Inc.-jtype-Full_Time-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dc-MUFG-jtype-Full_Time-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dc-Andiamo_Partners-jtype-Full_Time-radius-30-jobs.html
# #
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Full_Time-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Part_Time-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Contracts-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Contract_Independent-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Contract_W2-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-C2H_Independent-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-C2H_W2-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Third_Party-radius-30-jobs.html
# None
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Contract_Corp%26%2345To%26%2345Corp-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-C2H_Corp%26%2345To%26%2345Corp-radius-30-jobs.html
# https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dtco-true-jtype-Full_Time-radius-30-jobs.html
# None
# None
# None
# #
# #
# https://www.dice.com/company/amazon20
# https://www.dice.com/company/amazon20
# https://www.dice.com/jobs/detail/Software-Development-Engineer%2C-Data-Science-Amazon-Newark-NJ-07101/amazon20/446982?icid=sr1-1p&q=data science&l=New York, NY
# https://www.dice.com/company/amazon20
# https://www.dice.com/company/amazon20
# https://www.dice.com/company/10120942A
# https://www.dice.com/company/10120942A
# https://www.dice.com/jobs/detail/Lead-Data-Science-Developer-UPS-Mahwah-NJ-07430/10120942A/109312?icid=sr2-1p&q=data science&l=New York, NY
# https://www.dice.com/company/10120942A
# https://www.dice.com/company/10120942A
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/jobs/detail/Data-Engineer-for-a-Venture-Capital-find-Data-Science-team.-CyberCoders-New-York-NY-10001/cybercod/SBS-13226065?icid=sr3-1p&q=data science&l=New York, NY
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/jobs/detail/Data-Engineer-for-a-Venture-Capital-find-Data-Science-team.-CyberCoders-New-York-NY-10001/cybercod/SBS-13226066?icid=sr4-1p&q=data science&l=New York, NY
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/10116662
# https://www.dice.com/company/10116662
# https://www.dice.com/jobs/detail/Machine-Learning-and-Data-Science-Experts-Gambit-Technologies-New-York-NY-10001/10116662/SD480432373119466?icid=sr5-1p&q=data science&l=New York, NY
# https://www.dice.com/company/10116662
# https://www.dice.com/company/10116662
# https://www.dice.com/company/opensyst
# https://www.dice.com/company/opensyst
# https://www.dice.com/jobs/detail/Network-Data-Scientist-Open-Systems-Technologies-New-York-NY-10022/opensyst/31192?icid=sr6-1p&q=data science&l=New York, NY
# https://www.dice.com/company/opensyst
# https://www.dice.com/company/opensyst
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/jobs/detail/Data-Scientist-%26%2347-Quant-for-well-respected-NYC-hedge-%26%2347-VC-firm-CyberCoders-New-York-NY-10001/cybercod/SBS-13226075?icid=sr7-1p&q=data science&l=New York, NY
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/jobs/detail/Data-Scientist-%26%2347-Quant-for-well-respected-NYC-hedge-%26%2347-VC-firm-CyberCoders-New-York-NY-10001/cybercod/SBS-13226076?icid=sr8-1p&q=data science&l=New York, NY
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/precisn
# https://www.dice.com/company/precisn
# https://www.dice.com/jobs/detail/Sr.-Data-Scientist-%26%2345-Machine-Learning%2C-Python%2C-R%2C-Predictive-Analytics-%26%2347-Big-Data-Precision-Systems-New-York-NY-10001/precisn/3032DI?icid=sr9-1p&q=data science&l=New York, NY
# https://www.dice.com/company/precisn
# https://www.dice.com/company/precisn
# https://www.dice.com/company/10125751
# https://www.dice.com/company/10125751
# https://www.dice.com/jobs/detail/Data-Scientist-M2-Resources-Inc-New-York-NY-10285/10125751/686713?icid=sr10-1p&q=data science&l=New York, NY
# https://www.dice.com/company/10125751
# https://www.dice.com/company/10125751
# https://www.dice.com/company/insysus
# https://www.dice.com/company/insysus
# https://www.dice.com/jobs/detail/Data-Scientist-INSYS-Group-Warren-NJ-07059/insysus/16-01996?icid=sr11-1p&q=data science&l=New York, NY
# https://www.dice.com/company/insysus
# https://www.dice.com/company/insysus
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/jobs/detail/Data-Scientist-%26%2345-50%26%2337-Client-site%26%2345-50%26%2337-work-from-home%21-CyberCoders-New-York-NY-10001/cybercod/SBS-131719228?icid=sr12-1p&q=data science&l=New York, NY
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/jobs/detail/Data-Scientist-%26%2345-50%26%2337-Client-site%26%2345-50%26%2337-work-from-home%21-CyberCoders-New-York-NY-10001/cybercod/SBS-131719229?icid=sr13-1p&q=data science&l=New York, NY
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/jobs/detail/Senior-Economist-%26%2345-Fortune-500-company%26%2345-Media-facing%26%2345-SQL-CyberCoders-New-York-NY-10001/cybercod/JC7-131651630?icid=sr14-1p&q=data science&l=New York, NY
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/jobs/detail/Senior-Economist-%26%2345-Fortune-500-company%26%2345-Media-facing%26%2345-SQL-CyberCoders-New-York-NY-10001/cybercod/JC7-131651631?icid=sr15-1p&q=data science&l=New York, NY
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/jobs/detail/Senior-Data-Engineer-%26%2345-Healthcare-and-Life-Science-Analytics%21-%26%2345-CyberCoders-New-York-NY-10001/cybercod/MO1-130805869?icid=sr16-1p&q=data science&l=New York, NY
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/jobs/detail/Senior-Data-Engineer-%26%2345-Healthcare-and-Life-Science-Analytics%21-%26%2345-CyberCoders-New-York-NY-10001/cybercod/MO1-130805870?icid=sr17-1p&q=data science&l=New York, NY
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/10228857
# https://www.dice.com/company/10228857
# https://www.dice.com/jobs/detail/Executive-Director%2C-Research-Science-The-NPD-Group-Port-Washington-NY-11050/10228857/160417?icid=sr18-1p&q=data science&l=New York, NY
# https://www.dice.com/company/10228857
# https://www.dice.com/company/10228857
# https://www.dice.com/company/10340096
# https://www.dice.com/company/10340096
# https://www.dice.com/jobs/detail/Core-Java-Developer-with-Strong-Multi%26%2345threading-and-Computer-Science%21-Archer-I.T.%2C-LLC-Jersey-City-NJ-07310/10340096/bm052216?icid=sr19-1p&q=data science&l=New York, NY
# https://www.dice.com/company/10340096
# https://www.dice.com/company/10340096
# https://www.dice.com/company/10340096
# https://www.dice.com/company/10340096
# https://www.dice.com/jobs/detail/Junior-or-Mid%26%2345Level-Core-Java-Developer-Multi%26%2345threading-and-Comp-Sci%21-Archer-I.T.%2C-LLC-New-York-NY-10010/10340096/bm072616?icid=sr20-1p&q=data science&l=New York, NY
# https://www.dice.com/company/10340096
# https://www.dice.com/company/10340096
# https://www.dice.com/company/10483385
# https://www.dice.com/company/10483385
# https://www.dice.com/jobs/detail/Core-Java-Developer-with-Comp-Sci-and-Equity-Derivatives-Background%21-Rock-Recruiting-New-York-NY-10010/10483385/081816?icid=sr21-1p&q=data science&l=New York, NY
# https://www.dice.com/company/10483385
# https://www.dice.com/company/10483385
# https://www.dice.com/company/rtcons
# https://www.dice.com/company/rtcons
# https://www.dice.com/jobs/detail/Software-developer-%26%2345-Cu-Sci-2%2B-years-R-%26-T--Consulting-New-York-NY-10017/rtcons/266872?icid=sr22-1p&q=data science&l=New York, NY
# https://www.dice.com/company/rtcons
# https://www.dice.com/company/rtcons
# https://www.dice.com/company/10116662
# https://www.dice.com/company/10116662
# https://www.dice.com/jobs/detail/Seeking-talented-Computer-Science-graduates-for-a-tech%26%2345driven-hedge-fund-Gambit-Technologies-New-York-NY-10001/10116662/SD1431666179938?icid=sr23-1p&q=data science&l=New York, NY
# https://www.dice.com/company/10116662
# https://www.dice.com/company/10116662
# https://www.dice.com/company/10110787
# https://www.dice.com/company/10110787
# https://www.dice.com/jobs/detail/Senior-Data-Security-Engineer-British-Telecommunications-Public-Limited-Company-New-York-NY-10001/10110787/51519?icid=sr24-1p&q=data science&l=New York, NY
# https://www.dice.com/company/10110787
# https://www.dice.com/company/10110787
# https://www.dice.com/company/10514056
# https://www.dice.com/company/10514056
# https://www.dice.com/jobs/detail/Senior-Product-Manager-Twenty-Recruitment-Group-New-York-NY-10021/10514056/717750?icid=sr25-1p&q=data science&l=New York, NY
# https://www.dice.com/company/10514056
# https://www.dice.com/company/10514056
# https://www.dice.com/company/10108900
# https://www.dice.com/company/10108900
# https://www.dice.com/jobs/detail/Senior-Developer-%26%2345-Core-Platform-Offering-Evantage-LLC-New-York-NY-10001/10108900/538517?icid=sr26-1p&q=data science&l=New York, NY
# https://www.dice.com/company/10108900
# https://www.dice.com/company/10108900
# https://www.dice.com/company/90767815
# https://www.dice.com/company/90767815
# https://www.dice.com/jobs/detail/Algo-Quant-Strategist-Konnect-Partners-Jersey-City-NJ-07302/90767815/675141?icid=sr27-1p&q=data science&l=New York, NY
# https://www.dice.com/company/90767815
# https://www.dice.com/company/90767815
# https://www.dice.com/company/10294672
# https://www.dice.com/company/10294672
# https://www.dice.com/jobs/detail/C%2B%2B-Software-Developer-Futures-Group-IT-LLC.-New-York-NY-10018/10294672/MC_C%2B%2B_PR?icid=sr28-1p&q=data science&l=New York, NY
# https://www.dice.com/company/10294672
# https://www.dice.com/company/10294672
# https://www.dice.com/company/amazon20
# https://www.dice.com/company/amazon20
# https://www.dice.com/jobs/detail/Software-Development-Manager%2C-Data-Team-Amazon-Newark-NJ-07101/amazon20/446981?icid=sr29-1p&q=data science&l=New York, NY
# https://www.dice.com/company/amazon20
# https://www.dice.com/company/amazon20
# https://www.dice.com/company/10432313
# https://www.dice.com/company/10432313
# https://www.dice.com/jobs/detail/Senior-Data-Engineer-for-Search-and-Discoverability-Team-Bloomberg-L.P.-New-York-NY-10001/10432313/49862?icid=sr30-1p&q=data science&l=New York, NY
# https://www.dice.com/company/10432313
# https://www.dice.com/company/10432313
# #
# #
# https://www.dice.com/company/amazon20
# https://www.dice.com/company/amazon20
# https://www.dice.com/jobs/detail/Software-Development-Engineer%2C-Data-Science-Amazon-Newark-NJ-07101/amazon20/446982?icid=sr1-1p&q=data science&l=New York, NY
# https://www.dice.com/company/amazon20
# https://www.dice.com/company/amazon20
# https://www.dice.com/company/10120942A
# https://www.dice.com/company/10120942A
# https://www.dice.com/jobs/detail/Lead-Data-Science-Developer-UPS-Mahwah-NJ-07430/10120942A/109312?icid=sr2-1p&q=data science&l=New York, NY
# https://www.dice.com/company/10120942A
# https://www.dice.com/company/10120942A
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/jobs/detail/Data-Engineer-for-a-Venture-Capital-find-Data-Science-team.-CyberCoders-New-York-NY-10001/cybercod/SBS-13226065?icid=sr3-1p&q=data science&l=New York, NY
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/jobs/detail/Data-Engineer-for-a-Venture-Capital-find-Data-Science-team.-CyberCoders-New-York-NY-10001/cybercod/SBS-13226066?icid=sr4-1p&q=data science&l=New York, NY
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/10116662
# https://www.dice.com/company/10116662
# https://www.dice.com/jobs/detail/Machine-Learning-and-Data-Science-Experts-Gambit-Technologies-New-York-NY-10001/10116662/SD480432373119466?icid=sr5-1p&q=data science&l=New York, NY
# https://www.dice.com/company/10116662
# https://www.dice.com/company/10116662
# https://www.dice.com/company/opensyst
# https://www.dice.com/company/opensyst
# https://www.dice.com/jobs/detail/Network-Data-Scientist-Open-Systems-Technologies-New-York-NY-10022/opensyst/31192?icid=sr6-1p&q=data science&l=New York, NY
# https://www.dice.com/company/opensyst
# https://www.dice.com/company/opensyst
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/jobs/detail/Data-Scientist-%26%2347-Quant-for-well-respected-NYC-hedge-%26%2347-VC-firm-CyberCoders-New-York-NY-10001/cybercod/SBS-13226075?icid=sr7-1p&q=data science&l=New York, NY
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/jobs/detail/Data-Scientist-%26%2347-Quant-for-well-respected-NYC-hedge-%26%2347-VC-firm-CyberCoders-New-York-NY-10001/cybercod/SBS-13226076?icid=sr8-1p&q=data science&l=New York, NY
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/precisn
# https://www.dice.com/company/precisn
# https://www.dice.com/jobs/detail/Sr.-Data-Scientist-%26%2345-Machine-Learning%2C-Python%2C-R%2C-Predictive-Analytics-%26%2347-Big-Data-Precision-Systems-New-York-NY-10001/precisn/3032DI?icid=sr9-1p&q=data science&l=New York, NY
# https://www.dice.com/company/precisn
# https://www.dice.com/company/precisn
# https://www.dice.com/company/10125751
# https://www.dice.com/company/10125751
# https://www.dice.com/jobs/detail/Data-Scientist-M2-Resources-Inc-New-York-NY-10285/10125751/686713?icid=sr10-1p&q=data science&l=New York, NY
# https://www.dice.com/company/10125751
# https://www.dice.com/company/10125751
# https://www.dice.com/company/insysus
# https://www.dice.com/company/insysus
# https://www.dice.com/jobs/detail/Data-Scientist-INSYS-Group-Warren-NJ-07059/insysus/16-01996?icid=sr11-1p&q=data science&l=New York, NY
# https://www.dice.com/company/insysus
# https://www.dice.com/company/insysus
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/jobs/detail/Data-Scientist-%26%2345-50%26%2337-Client-site%26%2345-50%26%2337-work-from-home%21-CyberCoders-New-York-NY-10001/cybercod/SBS-131719228?icid=sr12-1p&q=data science&l=New York, NY
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/jobs/detail/Data-Scientist-%26%2345-50%26%2337-Client-site%26%2345-50%26%2337-work-from-home%21-CyberCoders-New-York-NY-10001/cybercod/SBS-131719229?icid=sr13-1p&q=data science&l=New York, NY
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/jobs/detail/Senior-Economist-%26%2345-Fortune-500-company%26%2345-Media-facing%26%2345-SQL-CyberCoders-New-York-NY-10001/cybercod/JC7-131651630?icid=sr14-1p&q=data science&l=New York, NY
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/jobs/detail/Senior-Economist-%26%2345-Fortune-500-company%26%2345-Media-facing%26%2345-SQL-CyberCoders-New-York-NY-10001/cybercod/JC7-131651631?icid=sr15-1p&q=data science&l=New York, NY
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/jobs/detail/Senior-Data-Engineer-%26%2345-Healthcare-and-Life-Science-Analytics%21-%26%2345-CyberCoders-New-York-NY-10001/cybercod/MO1-130805869?icid=sr16-1p&q=data science&l=New York, NY
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/jobs/detail/Senior-Data-Engineer-%26%2345-Healthcare-and-Life-Science-Analytics%21-%26%2345-CyberCoders-New-York-NY-10001/cybercod/MO1-130805870?icid=sr17-1p&q=data science&l=New York, NY
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/cybercod
# https://www.dice.com/company/10228857
# https://www.dice.com/company/10228857
# https://www.dice.com/jobs/detail/Executive-Director%2C-Research-Science-The-NPD-Group-Port-Washington-NY-11050/10228857/160417?icid=sr18-1p&q=data science&l=New York, NY
# https://www.dice.com/company/10228857
# https://www.dice.com/company/10228857
# https://www.dice.com/company/10340096
# https://www.dice.com/company/10340096
# https://www.dice.com/jobs/detail/Core-Java-Developer-with-Strong-Multi%26%2345threading-and-Computer-Science%21-Archer-I.T.%2C-LLC-Jersey-City-NJ-07310/10340096/bm052216?icid=sr19-1p&q=data science&l=New York, NY
# https://www.dice.com/company/10340096
# https://www.dice.com/company/10340096
# https://www.dice.com/company/10340096
# https://www.dice.com/company/10340096
# https://www.dice.com/jobs/detail/Junior-or-Mid%26%2345Level-Core-Java-Developer-Multi%26%2345threading-and-Comp-Sci%21-Archer-I.T.%2C-LLC-New-York-NY-10010/10340096/bm072616?icid=sr20-1p&q=data science&l=New York, NY
# https://www.dice.com/company/10340096
# https://www.dice.com/company/10340096
# https://www.dice.com/company/10483385
# https://www.dice.com/company/10483385
# https://www.dice.com/jobs/detail/Core-Java-Developer-with-Comp-Sci-and-Equity-Derivatives-Background%21-Rock-Recruiting-New-York-NY-10010/10483385/081816?icid=sr21-1p&q=data science&l=New York, NY
# https://www.dice.com/company/10483385
# https://www.dice.com/company/10483385
# https://www.dice.com/company/rtcons
# https://www.dice.com/company/rtcons
# https://www.dice.com/jobs/detail/Software-developer-%26%2345-Cu-Sci-2%2B-years-R-%26-T--Consulting-New-York-NY-10017/rtcons/266872?icid=sr22-1p&q=data science&l=New York, NY
# https://www.dice.com/company/rtcons
# https://www.dice.com/company/rtcons
# https://www.dice.com/company/10116662
# https://www.dice.com/company/10116662
# https://www.dice.com/jobs/detail/Seeking-talented-Computer-Science-graduates-for-a-tech%26%2345driven-hedge-fund-Gambit-Technologies-New-York-NY-10001/10116662/SD1431666179938?icid=sr23-1p&q=data science&l=New York, NY
# https://www.dice.com/company/10116662
# https://www.dice.com/company/10116662
# https://www.dice.com/company/10110787
# https://www.dice.com/company/10110787
# https://www.dice.com/jobs/detail/Senior-Data-Security-Engineer-British-Telecommunications-Public-Limited-Company-New-York-NY-10001/10110787/51519?icid=sr24-1p&q=data science&l=New York, NY
# https://www.dice.com/company/10110787
# https://www.dice.com/company/10110787
# https://www.dice.com/company/10514056
# https://www.dice.com/company/10514056
# https://www.dice.com/jobs/detail/Senior-Product-Manager-Twenty-Recruitment-Group-New-York-NY-10021/10514056/717750?icid=sr25-1p&q=data science&l=New York, NY
# https://www.dice.com/company/10514056
# https://www.dice.com/company/10514056
# https://www.dice.com/company/10108900
# https://www.dice.com/company/10108900
# https://www.dice.com/jobs/detail/Senior-Developer-%26%2345-Core-Platform-Offering-Evantage-LLC-New-York-NY-10001/10108900/538517?icid=sr26-1p&q=data science&l=New York, NY
# https://www.dice.com/company/10108900
# https://www.dice.com/company/10108900
# https://www.dice.com/company/90767815
# https://www.dice.com/company/90767815
# https://www.dice.com/jobs/detail/Algo-Quant-Strategist-Konnect-Partners-Jersey-City-NJ-07302/90767815/675141?icid=sr27-1p&q=data science&l=New York, NY
# https://www.dice.com/company/90767815
# https://www.dice.com/company/90767815
# https://www.dice.com/company/10294672
# https://www.dice.com/company/10294672
# https://www.dice.com/jobs/detail/C%2B%2B-Software-Developer-Futures-Group-IT-LLC.-New-York-NY-10018/10294672/MC_C%2B%2B_PR?icid=sr28-1p&q=data science&l=New York, NY
# https://www.dice.com/company/10294672
# https://www.dice.com/company/10294672
# https://www.dice.com/company/amazon20
# https://www.dice.com/company/amazon20
# https://www.dice.com/jobs/detail/Software-Development-Manager%2C-Data-Team-Amazon-Newark-NJ-07101/amazon20/446981?icid=sr29-1p&q=data science&l=New York, NY
# https://www.dice.com/company/amazon20
# https://www.dice.com/company/amazon20
# https://www.dice.com/company/10432313
# https://www.dice.com/company/10432313
# https://www.dice.com/jobs/detail/Senior-Data-Engineer-for-Search-and-Discoverability-Team-Bloomberg-L.P.-New-York-NY-10001/10432313/49862?icid=sr30-1p&q=data science&l=New York, NY
# https://www.dice.com/company/10432313
# https://www.dice.com/company/10432313
# #
# #
# http://www.dice.com
# http://insights.dice.com/about-dice/
# http://media.dice.com/
# https://employer.dice.com/daf/newContactDice.html
# http://www.dice.com/social
# http://www.dice.com/common/seeker/docs/dice_jobs.jsp
# http://www.dice.com/about/privacy
# http://www.dice.com/about/contactus
# http://media.dice.com/category/the-dice-report/
# /openweb
# /jobs/browse
# /skills
# http://be.dice.com/
# http://de.dice.com/
# http://nl.dice.com/
# http://sap.dice.com/
# http://uk.dice.com/
# https://twitter.com/Dicedotcom
# https://www.facebook.com/dice
# https://plus.google.com/+Dice/posts
# http://c00.adobe.com/d53bf41a-0d61-47b4-b7f1-6df9b46831cf/DI_OS_UN_MA_UP/i/794201100
# http://c00.adobe.com/d53bf41a-0d61-47b4-b7f1-6df9b46831cf/DI_OS_UN_MA_UP/g/com.dice.app.jobs
# http://www.dice.com/about/terms_and_conditions
# http://www.dhigroupinc.com
# http://www.dice.com/profman/resetPassword.jsp
# /register
# mailto:newdicesupport@dice.com

# %%
soup.name
# Out:
# u'[document]'

# %%
soup.a.contents()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-ed180529ba56> in <module>()
# ----> 1 soup.a.contents()
#
# TypeError: 'list' object is not callable

# %%
"""from scrapy import Spider
from indeed.items import IndeedItem
from scrapy.selector import Selector
from selenium import webdriver
from scrapy.http import TextResponse
import scrapy


class IndeedSpider(Spider):
    name = 'indeed'

    allowed_domains = ["http://www.dice.com/"]

    s1 = 'https://www.dice.com/jobs/q-data_scientist-limit-30-l-New_York%2C_NY-radius-30-startPage-1-limit-30-jobs?searchid=291607343849'

    start_urls = [s1]

    def __init__(self):
        self.driver = webdriver.Chrome()

    def parse(self, response):

        self.driver.get(response.url)
        urls = []

        for i in range(1,20):
        
            response = TextResponse(url=self.driver.current_url, body=self.driver.page_source, encoding='utf-8')
            self.driver.implicitly_wait(10)

            for j in range(1, 31):
                result = response.xpath('//*[@class="col-md-9"]/div[1]/div['+str(j)+']/h3/a/@href')
                urls.extend(result)

            next_page = self.driver.find_element_by_xpath('//*[@title="Go to next page"]')
            next_page.click()"""
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-e68393acaca3> in <module>()
# ----> 1 from scrapy import Spider
#       2 from indeed.items import IndeedItem
#       3 from scrapy.selector import Selector
#       4 from selenium import webdriver
#       5 from scrapy.http import TextResponse
#
# ImportError: No module named scrapy

# %%
"""for href in urls:
            print href
            url = href.extract()
            self.driver.get(url)
            response = TextResponse(url=self.driver.current_url, body=self.driver.page_source, encoding='utf-8')
            item = IndeedItem()

            for sel in response.xpath('//div[@class="col-md-5 col-lg-6"]'):
                item['job_title'] = sel.xpath('//div[@class="col-md-5 col-lg-6"]/h1/text()').extract()
                item['location'] = sel.xpath('//div[@class="col-md-5 col-lg-6"]/ul/li[2]/text()').extract()
                item['company_name'] = sel.xpath('//div[@class="col-md-5 col-lg-6"]/ul/li[1]/a/text()').extract()

            for sel_1 in response.xpath('//*[@id="bd"]/div/div[1]'):
                item['job_type'] = sel_1.xpath('//div[2]/div/div[2]/span/text()').extract()
                item['job_salary'] = sel_1.xpath('//div[3]/div/div[2]/span/text()').extract()


            yield item


        self.driver.close()"""

# %%
https://www.dice.com/jobs/detail/Data-Scientist-3%26%23474-NORTHROP-GRUMMAN-Redondo-Beach-CA-90277/ngitbot/16024151?icid=sr4-1p&q=data%20scientist&l=

# %%
r3 = requests.get('https://www.dice.com/jobs/detail/Data-Scientist-3%26%23474-NORTHROP-GRUMMAN-Redondo-Beach-CA-90277/ngitbot/16024151?icid=sr4-1p&q=data%20scientist&l=')

soup3 = BeautifulSoup(r2.content, "lxml")

# %%
soup3
# Out:
# <!DOCTYPE html>\n<html>\n<head>\n<meta charset="unicode-escape"/>\n<meta content="IE=edge" http-equiv="X-UA-Compatible"/>\n<meta content="width=device-width, initial-scale=1" name="viewport"/>\n<meta content="Job_Search_Results" name="ompagename"/>\n<meta content="tech pro" name="channel"/>\n<title>Full-Time data science jobs in New York, NY | Dice.com</title>\n<meta content="2,963 Full-Time data science jobs in New York, NY on Dice.com. Find your next tech job." name="description"/>\n<meta content="Full-Time data science jobs in New York, NY, tech jobs, it jobs, recruitment,  careers,  employment,  job listings,  job search,  search engine, work in" name="keywords"/>\n<link href="https://www.dice.com/jobs/q-data_science-jtype-Full+Time-limit-30-l-New_York%2C_NY-radius-30-jobs.html" rel="canonical"/>\n<link href="https://www.dice.com/jobs/q-data_science-jtype-Full+Time-limit-30-l-New_York%2C_NY-radius-30-startPage-2-jobs.html" rel="next"/>\n<link href="//fonts.googleapis.com/css?family=Roboto+Condensed" rel="stylesheet"/>\n<link href="//assets.dice.com/techpro/img/favicons/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>\n<link href="//assets.dice.com/techpro/img/favicons/apple-touch-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>\n<link href="//assets.dice.com/techpro/img/favicons/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>\n<link href="//assets.dice.com/techpro/img/favicons/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>\n<link href="//assets.dice.com/techpro/img/favicons/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>\n<link href="//assets.dice.com/techpro/img/favicons/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>\n<link href="//assets.dice.com/techpro/img/favicons/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>\n<link href="//assets.dice.com/techpro/img/favicons/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>\n<link href="//assets.dice.com/techpro/img/favicons/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>\n<link href="//assets.dice.com/techpro/img/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>\n<link href="//assets.dice.com/techpro/img/favicons/favicon-194x194.png" rel="icon" sizes="194x194" type="image/png"/>\n<link href="//assets.dice.com/techpro/img/favicons/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>\n<link href="//assets.dice.com/techpro/img/favicons/android-chrome-192x192.png" rel="icon" sizes="192x192" type="image/png"/>\n<link href="//assets.dice.com/techpro/img/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>\n<link href="//assets.dice.com/techpro/img/favicons/manifest.json" rel="manifest"/>\n<link href="//assets.dice.com/techpro/img/favicons/favicon.ico" rel="shortcut icon"/>\n<meta content="Dice" name="apple-mobile-web-app-title"/>\n<meta content="Dice" name="application-name"/>\n<meta content="#cc0000" name="msapplication-TileColor"/>\n<meta content="//assets.dice.com/techpro/img/favicons/mstile-144x144.png" name="msapplication-TileImage"/>\n<meta content="//assets.dice.com/techpro/img/favicons/browserconfig.xml" name="msapplication-config"/>\n<meta content="#cc0000" name="theme-color"/>\n<script type="text/javascript">var signFromGoogleOutVal = false;</script>\n<link href="//assets.dice.com/techpro/css/job-search.min.css" rel="stylesheet"/>\n<script src="//assets.adobedtm.com/8c06f57f0590fbbe830e2dd0366687c0599684e7/satelliteLib-73044e29039c50f90968e5135f6f50a83641e7f0.js"></script>\n<!-- Begin Monetate tag v6. Place at start of document head. DO NOT ALTER. -->\n<script type="text/javascript">\n    var monetateT = new Date().getTime();\n    (function() {\n        var p = document.location.protocol;\n        if (p == "http:" || p == "https:") {\n            if (true === true) {//For PROD & QA\n                var m = document.createElement('script'); m.type = 'te ...

# %%
print soup3.prettify()
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="Job_Search_Results" name="ompagename"/>
#   <meta content="tech pro" name="channel"/>
#   <title>
#    Full-Time data science jobs in New York, NY | Dice.com
#   </title>
#   <meta content="2,963 Full-Time data science jobs in New York, NY on Dice.com. Find your next tech job." name="description"/>
#   <meta content="Full-Time data science jobs in New York, NY, tech jobs, it jobs, recruitment,  careers,  employment,  job listings,  job search,  search engine, work in" name="keywords"/>
#   <link href="https://www.dice.com/jobs/q-data_science-jtype-Full+Time-limit-30-l-New_York%2C_NY-radius-30-jobs.html" rel="canonical"/>
#   <link href="https://www.dice.com/jobs/q-data_science-jtype-Full+Time-limit-30-l-New_York%2C_NY-radius-30-startPage-2-jobs.html" rel="next"/>
#   <link href="//fonts.googleapis.com/css?family=Roboto+Condensed" rel="stylesheet"/>
#   <link href="//assets.dice.com/techpro/img/favicons/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
#   <link href="//assets.dice.com/techpro/img/favicons/apple-touch-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
#   <link href="//assets.dice.com/techpro/img/favicons/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
#   <link href="//assets.dice.com/techpro/img/favicons/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
#   <link href="//assets.dice.com/techpro/img/favicons/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
#   <link href="//assets.dice.com/techpro/img/favicons/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
#   <link href="//assets.dice.com/techpro/img/favicons/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
#   <link href="//assets.dice.com/techpro/img/favicons/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
#   <link href="//assets.dice.com/techpro/img/favicons/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="//assets.dice.com/techpro/img/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="//assets.dice.com/techpro/img/favicons/favicon-194x194.png" rel="icon" sizes="194x194" type="image/png"/>
#   <link href="//assets.dice.com/techpro/img/favicons/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
#   <link href="//assets.dice.com/techpro/img/favicons/android-chrome-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
#   <link href="//assets.dice.com/techpro/img/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="//assets.dice.com/techpro/img/favicons/manifest.json" rel="manifest"/>
#   <link href="//assets.dice.com/techpro/img/favicons/favicon.ico" rel="shortcut icon"/>
#   <meta content="Dice" name="apple-mobile-web-app-title"/>
#   <meta content="Dice" name="application-name"/>
#   <meta content="#cc0000" name="msapplication-TileColor"/>
#   <meta content="//assets.dice.com/techpro/img/favicons/mstile-144x144.png" name="msapplication-TileImage"/>
#   <meta content="//assets.dice.com/techpro/img/favicons/browserconfig.xml" name="msapplication-config"/>
#   <meta content="#cc0000" name="theme-color"/>
#   <script type="text/javascript">
#    var signFromGoogleOutVal = false;
#   </script>
#   <link href="//assets.dice.com/techpro/css/job-search.min.css" rel="stylesheet"/>
#   <script src="//assets.adobedtm.com/8c06f57f0590fbbe830e2dd0366687c0599684e7/satelliteLib-73044e29039c50f90968e5135f6f50a83641e7f0.js">
#   </script>
#   <!-- Begin Monetate tag v6. Place at start of document head. DO NOT ALTER. -->
#   <script type="text/javascript">
#    var monetateT = new Date().getTime();
#     (function() {
#         var p = document.location.protocol;
#         if (p == "http:" || p == "https:") {
#             if (true === true) {//For PROD & QA
#                 var m = document.createElement('script'); m.type = 'text/javascript'; m.async = true; m.src = (p == "https:" ? "https://s" : "http://") + "b.monetate.net/js/1/a-49445784/p/dice.com/" + Math.floor((monetateT + 1615620) / 3600000) + "/g";
#                 var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(m, s);
#             } else {//Only for PILOT
#                 var m = document.createElement("script"); m.type = "text/javascript"; m.src = (p == "https:" ? "https://s" : "http://") + "e.monetate.net/js/2/a-49445784/d/dicepilot.com/entry.js";
#                 var e = document.createElement("div"); e.appendChild(m); document.write(e.innerHTML);
#             }
#         }
#     })();
#   </script>
#   <!-- End Monetate tag. -->
#   <script type="text/javascript">
#    var diceJSON = {page : 1, pageCount : 99 , limit : 30} ;
# 		/* function errorImg(obj) {
# 			console.log("obj.src == "+obj.src);
# 			$(obj).hide();
# 			$(obj).parent().siblings('.circle').show();
# 		} */
#   </script>
#  </head>
#  <body>
#   <!--JS required parameter Start-->
#   <input id="sort" name="sort" type="hidden" value=""/>
#   <input id="searchType" name="searchType" type="hidden" value="basic"/>
#   <input id="pageNo" name="pageNo" type="hidden" value="1"/>
#   <input id="loc" name="loc" type="hidden" value="New York, NY"/>
#   <input id="savesearch" type="hidden" value="false"/>
#   <input id="newSearch" type="hidden" value="false"/>
#   <input id="rJobFlag" type="hidden" value="false"/>
#   <input id="hideViewedJobsEnable" type="hidden" value="false"/>
#   <!--
# -->
#   <input id="jtype" name="jtype" type="hidden" value="Full Time"/>
#   <input id="radius" name="radius" type="hidden" value="30"/>
#   <!--JS required parameter End-->
#   <!--Company Logo required parameter Start-->
#   <!-- header and search box section Start -->
#   <!-- HEADER CODE -->
#   <div class="dice-navbar" role="navigation">
#    <div class="container">
#     <div class="navbar-header">
#      <button class="navbar-toggle nbt" data-target="#menu-toggle" type="button">
#       <span class="sr-only">
#        Toggle navigation
#       </span>
#       <span class="icon-bar">
#       </span>
#       <span class="icon-bar">
#       </span>
#       <span class="icon-bar">
#       </span>
#      </button>
#      <button class="navbar-toggle nbt navbar-magnifier search" data-target="#search-toggle" type="button">
#       <span class="icon icon-magnifier searchspan">
#       </span>
#      </button>
#      <div class="dice-navbar-brand">
#       <a class="logo" href="http://www.dice.com">
#       </a>
#      </div>
#     </div>
#     <div class="collapse navbar-collapse" id="menu-toggle" style="max-height: 100% !important;">
#      <div>
#       <!-- MOBILE -->
#       <ul class="nav navbar-nav ">
#        <li class="dropdown">
#         <a class="dropdown-toggle smartMenu btn-link" data-target="#smart-toggle1" id="smart-toggle-Career">
#          Tech Careers
#          <i class="icon-arrow-68">
#          </i>
#          <i class="icon-arrow-67">
#          </i>
#         </a>
#         <ul class="dropdown-menu dropdown-smartMenu" id="smart-toggle1">
#          <!-- <span class="open"></span> -->
#          <li>
#           <a href="/jobs">
#            Job Search
#           </a>
#          </li>
#          <li>
#           <a href="/skills">
#            Skills Center
#           </a>
#          </li>
#          <li>
#           <a href="https://www.dice.com/mobile">
#            Dice Careers Mobile
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li>
#         <a href="http://insights.dice.com/career-toolkit/">
#          Career Center
#         </a>
#        </li>
#        <li>
#         <a href="http://insights.dice.com/">
#          Insights
#         </a>
#        </li>
#       </ul>
#       <ul class="nav navbar-nav navbar-right visible-xs visible-sm">
#        <li>
#         <a href="http://www.dice.com/products/webstore">
#          Post Jobs
#         </a>
#        </li>
#        <li>
#         <a href="http://www.dice.com/products">
#          Talent Solutions
#         </a>
#        </li>
#        <li>
#         <a class="btn-link" href="/dashboard/login">
#          Login/Register
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div>
#       <!-- DESKTOP -->
#       <ul class="nav navbar-nav navbar-right hidden-xs hidden-sm">
#        <li>
#         <a href="http://www.dice.com/products/webstore">
#          Post Jobs
#         </a>
#        </li>
#        <li>
#         <a href="http://www.dice.com/products">
#          Talent Solutions
#         </a>
#        </li>
#        <li>
#         <a class="btn-link" href="/dashboard/login">
#          Login/Register
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <!--/.nav-collapse -->
#    </div>
#    <!-- END CONTAINER -->
#   </div>
#   <!-- END DICE-NAVBAR -->
#   <!-- END HEADER CODE -->
#   <div class="delaccMsgSec" id="delaccMsgSec">
#    <div class="container">
#     <div class="row">
#      <div class="col-md-9">
#       Your account has successfully been deleted. We're sorry to see you go!
#      </div>
#      <div class="col-md-3">
#       <a class="pull-right" href="#" id="hideDelMsg">
#        Hide this message
#       </a>
#      </div>
#     </div>
#    </div>
#   </div>
#   <!-- For label uncomment these lines and replace dice-float-label-on class with diceFloatLabelOnQ and diceFloatLabelOnL-->
#   <input id="settingDefaulteJobTypes" type="hidden" value="false"/>
#   <input id="defaulteJobTypes" type="hidden" value="Full Time"/>
#   <input id="pcip" type="hidden" value="208.185.23.206"/>
#   <div class="hidden-xs hidden-sm page-header navbar-collapse" id="search-toggle">
#    <div class="container form-horizontal dice-job-search">
#     <form action="https://www.dice.com/jobs" id="searchJob" method="get">
#      <div class="form-group">
#       <div class="col-sm-5 col-md-6 keyword-field dice-float-label dice-float-label-on">
#        <label for="job">
#         job title, skills, keywords or company name
#        </label>
#        <input autocomplete="off" class="form-control input-lg" id="job" maxlength="512" name="q" type="text" value="data science"/>
#        <div class="spacer hidden-lg hidden-md">
#        </div>
#        <span class="inputicon-magnifier icon-magnifier">
#        </span>
#       </div>
#       <div class="col-sm-4 col-md-3 location-field dice-float-label dice-float-label-on">
#        <label for="location">
#         zip code, city or state
#        </label>
#        <input autocomplete="off" class="form-control input-lg" id="location" maxlength="512" name="l" style="padding-right: 0px;" type="text" value="New York, NY"/>
#        <span class="inputicon-compass-3 icon-compass-3">
#        </span>
#        <div class="spacer hidden-lg hidden-md">
#        </div>
#       </div>
#       <div class="col-sm-3 find-jobs-field">
#        <input class="btn btn-lg btn-primary btn-block dice-btn mB5" onclick="getData()" type="button" value="Find Tech Jobs"/>
#        <a class="dice-btn-link" href="https://www.dice.com/jobs/advancedSearch.html">
#         Advanced Search
#        </a>
#       </div>
#       <!-- hide the filter job notification page -->
#       <div class="col-md-6 col-sm-9 col-xs-9 col-lg-6 globalSearchFilterCheck">
#        <span class="chklabel">
#         <input class="typeChkBox" type="checkbox" value="Full Time"/>
#         <a class="hjtype tjth" href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Full-Time
#         </a>
#        </span>
#        <span class="chklabel">
#         <input class="typeChkBox" type="checkbox" value="Part Time"/>
#         <a class="hjtype tjth" href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Part_Time-radius-30-jobs.html" rel="nofollow">
#          Part-Time
#         </a>
#        </span>
#        <span class="chklabel">
#         <input class="typeChkBox" type="checkbox" value="Contracts"/>
#         <a class="hjtype tjth" href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Contracts-radius-30-jobs.html" rel="nofollow">
#          Contracts
#         </a>
#        </span>
#        <span class="chklabel last">
#         <input class="typeChkBox" type="checkbox" value="Third Party"/>
#         <a class="hjtype tjth" href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Third_Party-radius-30-jobs.html" rel="nofollow">
#          Third Party
#         </a>
#         <a class="thirdPartyModal" data-target="#3rdparty" data-toggle="modal">
#          <i class="icon icon-question-mark">
#          </i>
#         </a>
#        </span>
#       </div>
#      </div>
#     </form>
#    </div>
#   </div>
#   <div class="modal fade" id="3rdparty" role="dialog">
#    <div class="modal-dialog">
#     <div class="modal-content">
#      <div class="modal-header">
#       <button aria-hidden="true" class="close" data-dismiss="modal" type="button">
#        ×
#       </button>
#       <h3>
#        What does selecting Third Party mean?
#       </h3>
#       <script src="//">
#       </script>
#       <meta content="what_is_thirdparty_modal" name="ompagename"/>
#       <meta content="tech pro" name="channel"/>
#      </div>
#      <div class="modal-body">
#       <p>
#        Selecting Third Party means you are a recruiter or staffing agency representing a tech professional to apply for Contract Corp-to-Corp and/or Contract-to-Hire Corp-to-Corp jobs.
#       </p>
#       <p>
#        If you are a tech professional who wants to directly apply for jobs, do NOT select Third Party.
#       </p>
#      </div>
#      <div class="modal-footer">
#       <a class="btn btn-primary" data-dismiss="modal" href="#">
#        Close
#       </a>
#      </div>
#     </div>
#     <!--  END MODAL CONTENT  -->
#    </div>
#    <!--  END MODAL DIALOG  -->
#   </div>
#   <!--  END THIRD PARTY MODAL  -->
#   <!-- header and search box section End -->
#   <!-- search result section Start -->
#   <div class="container jobs-container">
#    <div class="row hidden-xs">
#     <div class="col-md-9 col-md-offset-3">
#      <div class="top-ad">
#       <!-- Start: GPT Async -->
#       <script type="text/javascript">
#        var gptadslots=[];
#                         var googletag = googletag || {};
#                         googletag.cmd = googletag.cmd || [];
#                         (function(){ var gads = document.createElement('script');
#                             gads.async = true; gads.type = 'text/javascript';
#                             var useSSL = 'https:' == document.location.protocol;
#                             gads.src = (useSSL ? 'https:' : 'http:') + '//www.googletagservices.com/tag/js/gpt.js';
#                             var node = document.getElementsByTagName('script')[0];
#                             node.parentNode.insertBefore(gads, node);
#                         })();
#       </script>
#       <script type="text/javascript">
#        googletag.cmd.push(function() {
#
#                             //Adslot 1 declaration
#                             gptadslots[1]= googletag.defineSlot('/4140/dice/job_tools', [[728,90]],'div-gpt-ad-136689231299775354-1').addService(googletag.pubads());
#
#                             //Adslot 2 declaration
#                             gptadslots[2]= googletag.defineSlot('/4140/dice/jobsearch', [[160,600]],'div-gpt-ad-136689231299775354-2').addService(googletag.pubads());
#
#                             googletag.pubads().setTargeting('kw',['java']);
#                             googletag.pubads().enableAsyncRendering();
#                             googletag.enableServices();
#                         });
#       </script>
#       <script type="text/javascript">
#        googletag.cmd.push(function() {
#                             googletag.defineSlot('/4140/Dice/job_tools', [728, 90], 'div-gpt-ad-1460157222649-0').addService(googletag.pubads());
#
#                             googletag.defineSlot('/4140/Dice', [160, 320], 'div-gpt-ad-1472586159694-3').addService(googletag.pubads()).setTargeting('kw',['']).setCollapseEmptyDiv(true);
#
#                             googletag.pubads().enableSingleRequest();
#                             googletag.enableServices();
#                         });
#       </script>
#       <!-- End: GPT -->
#       <!-- /4140/Dice/job_tools -->
#       <div id="div-gpt-ad-1460157222649-0" style="height:90px; width:728px;">
#        <script type="text/javascript">
#         googletag.cmd.push(function() { googletag.display('div-gpt-ad-1460157222649-0'); });
#        </script>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="notifications top-right">
#    </div>
#    <div class="row">
#     <!-- search result left section Start -->
#     <!-- hide the filter job notification page -->
#     <div class="col-md-3 hidden-xs hidden-sm" id="filterSec">
#      <!-- search result left section for Recent Searches Start -->
#      <!-- search result left section for Recent Searches End -->
#      <!-- search result left section for Reset and Filter Start -->
#      <div class="page-header-custom" id="resetSec">
#       <div class="row">
#        <div class="col-xs-12">
#         <h2 class="pull-left h2 hidden-xs hidden-sm">
#          <span class="icon-filter-3">
#          </span>
#          Filter Results
#         </h2>
#         <a class="btn dice-btn-active hidden-md hidden-lg" onclick="toggleFilter()">
#          Filter
#         </a>
#         <a class="reset-btn dice-btn-link pull-right hidden-xs hidden-sm" href="#" id="reset-d">
#          Reset
#         </a>
#         <a class="btn dice-btn-secondary pull-right hidden-md hidden-lg" href="#" id="reset-m">
#          Reset
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- search result left section for Reset and Filter End -->
#      <!-- search result left section for Distance, Title, Company, Employment Type and Company Segment Start -->
#      <!-- Company Segment Section Start from here -->
#      <div class="page-header-custom" id="companySegments">
#       <div class="fh">
#        Company Segment
#        <span class="icon-filled-add-1 pull-right">
#        </span>
#       </div>
#       <div class="default" style="display:none;">
#        <div class="filter-option">
#         <input chktyp="dcs" chkval="Recruiter" class="fchk csck" type="checkbox" value="Recruiter"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dcs-Recruiter-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Recruiter
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="dcs" chkval="DirectHire" class="fchk csck" type="checkbox" value="DirectHire"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dcs-DirectHire-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          DirectHire
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- Company Segment Section End from here -->
#      <!-- Radius Section Start from here -->
#      <input id="distanceInMiles" type="hidden" value="true"/>
#      <div class="page-header-custom" id="locationMiles">
#       <div class="fh">
#        Distance
#        <span class="icon-filled-add-1 pull-right">
#        </span>
#       </div>
#       <div class="default" style="display:none;">
#        <div class="filter-option">
#         <input chktyp="radius" chkval="El" class="fchk rchk" type="checkbox"/>
#         Exact Location
#        </div>
#        <div class="filter-option">
#         <input chktyp="radius" chkval="5" class="fchk rchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Full_Time-radius-5-jobs.html" rel="nofollow">
#          Within 5 miles
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="radius" chkval="10" class="fchk rchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Full_Time-radius-10-jobs.html" rel="nofollow">
#          Within 10 miles
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="radius" chkval="20" class="fchk rchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Full_Time-radius-20-jobs.html" rel="nofollow">
#          Within 20 miles
#         </a>
#        </div>
#        <div class="filter-option">
#         <input checked="checked" chktyp="radius" chkval="30" class="fchk sel rchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Within 30 miles
#         </a>
#        </div>
#        <div class="mTB2">
#         <a class="m" href="#" onclick="javascript:displayfullcontent(this);javascript:return false;">
#          more
#         </a>
#        </div>
#       </div>
#       <div class="more disNon">
#        <div class="filter-option">
#         <input chktyp="radius" chkval="40" class="fchk rchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Full_Time-radius-40-jobs.html" rel="nofollow">
#          Within 40 miles
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="radius" chkval="50" class="fchk rchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Full_Time-radius-50-jobs.html" rel="nofollow">
#          Within 50 miles
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="radius" chkval="75" class="fchk rchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Full_Time-radius-75-jobs.html" rel="nofollow">
#          Within 75 miles
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="radius" chkval="100" class="fchk rchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Full_Time-radius-100-jobs.html" rel="nofollow">
#          Within 100 miles
#         </a>
#        </div>
#        <div class="mTB2">
#         <a class="l" href="#" onclick="javascript:displayfullcontent(this);javascript:return false;">
#          less
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- Radius Section End from here -->
#      <!-- Position Title Section Start from here -->
#      <div class="page-header-custom" id="positionTitle">
#       <div class="fh">
#        Title
#        <span class="icon-filled-add-1 pull-right">
#        </span>
#       </div>
#       <div class="default" style="display:none;">
#        <div class="filter-option">
#         <input chktyp="djt" chkval="Software+Development+Engineer" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-djt-Software_Development_Engineer-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Software Development Engineer
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="djt" chkval="Network+Engineer" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-djt-Network_Engineer-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Network Engineer
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="djt" chkval="Java+Developer" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-djt-Java_Developer-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Java Developer
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="djt" chkval="Business+Analyst" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-djt-Business_Analyst-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Business Analyst
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="djt" chkval="Software+Engineer" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-djt-Software_Engineer-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Software Engineer
#         </a>
#        </div>
#        <div class="mTB2">
#         <a class="m" href="#" onclick="javascript:displayfullcontent(this);javascript:return false;">
#          more
#         </a>
#        </div>
#       </div>
#       <div class="more disNon">
#        <div class="filter-option">
#         <input chktyp="djt" chkval="Data+Scientist" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-djt-Data_Scientist-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Data Scientist
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="djt" chkval="Senior+Java+Developer" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-djt-Senior_Java_Developer-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Senior Java Developer
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="djt" chkval="C%2B%2B+Developer" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-djt-C%2B%2B_Developer-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          C++ Developer
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="djt" chkval="Full+Stack+Developer" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-djt-Full_Stack_Developer-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Full Stack Developer
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="djt" chkval="Data+Analyst" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-djt-Data_Analyst-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Data Analyst
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="djt" chkval="Software+Development+Manager" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-djt-Software_Development_Manager-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Software Development Manager
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="djt" chkval="DevOps+Engineer" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-djt-DevOps_Engineer-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          DevOps Engineer
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="djt" chkval="Network+Administrator" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-djt-Network_Administrator-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Network Administrator
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="djt" chkval="Principal+%26%2345+Business+Consulting" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-djt-Principal_%26%2345_Business_Consulting-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Principal - Business Consultin
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="djt" chkval="SQL+Developer" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-djt-SQL_Developer-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          SQL Developer
#         </a>
#        </div>
#        <div class="mTB2">
#         <a class="l" href="#" onclick="javascript:displayfullcontent(this);javascript:return false;">
#          less
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- Position Title Section End from here -->
#      <!-- Location Section Start from here -->
#      <div class="page-header-custom" id="locations">
#       <div class="fh">
#        Location
#        <span class="icon-filled-add-1 pull-right">
#        </span>
#       </div>
#       <div class="default" style="display:none;">
#        <div class="filter-option">
#         <input checked="checked" chktyp="l" chkval="New York, NY" class="fchk sel" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          New York, NY
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="l" chkval="Jersey City, NJ" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-Jersey_City%2C_NJ-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Jersey City, NJ
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="l" chkval="New York City, NY" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York_City%2C_NY-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          New York City, NY
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="l" chkval="Newark, NJ" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-Newark%2C_NJ-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Newark, NJ
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="l" chkval="Parsippany, NJ" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-Parsippany%2C_NJ-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Parsippany, NJ
#         </a>
#        </div>
#        <div class="mTB2">
#         <a class="m" href="#" onclick="javascript:displayfullcontent(this);javascript:return false;">
#          more
#         </a>
#        </div>
#       </div>
#       <div class="more disNon">
#        <div class="filter-option">
#         <input chktyp="l" chkval="Edison, NJ" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-Edison%2C_NJ-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Edison, NJ
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="l" chkval="Nyc, NY" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-Nyc%2C_NY-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Nyc, NY
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="l" chkval="Brooklyn, NY" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-Brooklyn%2C_NY-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Brooklyn, NY
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="l" chkval="Manhattan, NY" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-Manhattan%2C_NY-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Manhattan, NY
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="l" chkval="Warren, NJ" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-Warren%2C_NJ-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Warren, NJ
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="l" chkval="Greenwich, CT" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-Greenwich%2C_CT-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Greenwich, CT
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="l" chkval="Piscataway, NJ" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-Piscataway%2C_NJ-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Piscataway, NJ
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="l" chkval="White Plains, NY" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-White_Plains%2C_NY-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          White Plains, NY
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="l" chkval="Rockleigh, NJ" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-Rockleigh%2C_NJ-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Rockleigh, NJ
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="l" chkval="Yonkers, NY" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-Yonkers%2C_NY-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Yonkers, NY
#         </a>
#        </div>
#        <div class="mTB2">
#         <a class="l" href="#" onclick="javascript:displayfullcontent(this);javascript:return false;">
#          less
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- Location Title Section End from here -->
#      <!-- Company Section Start from here -->
#      <div class="page-header-custom" id="companies">
#       <div class="fh">
#        Company
#        <span class="icon-filled-add-1 pull-right">
#        </span>
#       </div>
#       <div class="default" style="display:none;">
#        <div class="filter-option">
#         <input chktyp="dc" chkval="CyberCoders" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dc-CyberCoders-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          CyberCoders
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="dc" chkval="Amazon" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dc-Amazon-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Amazon
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="dc" chkval="Deloitte" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dc-Deloitte-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Deloitte
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="dc" chkval="Gambit+Technologies" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dc-Gambit_Technologies-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Gambit Technologies
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="dc" chkval="Robert+Half+Technology" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dc-Robert_Half_Technology-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Robert Half Technology
#         </a>
#        </div>
#        <div class="mTB2">
#         <a class="m" href="#" onclick="javascript:displayfullcontent(this);javascript:return false;">
#          more
#         </a>
#        </div>
#       </div>
#       <div class="more disNon">
#        <div class="filter-option">
#         <input chktyp="dc" chkval="Bebee+Affinity+Social+Network" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dc-Bebee_Affinity_Social_Network-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Bebee Affinity Social Network
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="dc" chkval="Bloomberg+L.P." class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dc-Bloomberg_L.P.-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Bloomberg L.P.
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="dc" chkval="Mitchell+Martin" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dc-Mitchell_Martin-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Mitchell Martin
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="dc" chkval="Software+Guidance+%26+Assistance" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dc-Software_Guidance_%26_Assistance-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Software Guidance &amp; Assistance
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="dc" chkval="Princeton+Information+Ltd" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dc-Princeton_Information_Ltd-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Princeton Information Ltd
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="dc" chkval="Crestron+Electronics+Inc" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dc-Crestron_Electronics_Inc-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Crestron Electronics Inc
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="dc" chkval="Kforce+Inc." class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dc-Kforce_Inc.-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Kforce Inc.
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="dc" chkval="Mitchell+Martin%2C+Inc." class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dc-Mitchell_Martin%2C_Inc.-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Mitchell Martin, Inc.
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="dc" chkval="MUFG" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dc-MUFG-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          MUFG
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="dc" chkval="Andiamo+Partners" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dc-Andiamo_Partners-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Andiamo Partners
#         </a>
#        </div>
#        <div class="mTB2">
#         <a class="l" href="#" onclick="javascript:displayfullcontent(this);javascript:return false;">
#          less
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- Company Section End from here -->
#      <!-- EMPLOYMENT_TYPE Section Start from here -->
#      <div class="page-header-custom" id="jobTypes">
#       <div class="fh">
#        Employment Type
#        <span class="icon-filled-add-1 pull-right">
#        </span>
#       </div>
#       <div class="default" style="display:none;">
#        <div class="filter-option">
#         <input checked="checked" chktyp="jtype" chkval="Full+Time" class="fchk sel" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Full-Time
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="jtype" chkval="Part+Time" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Part_Time-radius-30-jobs.html" rel="nofollow">
#          Part-Time
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="jtype" chkval="Contracts" class="cfchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Contracts-radius-30-jobs.html" rel="nofollow">
#          Contracts
#         </a>
#        </div>
#       </div>
#       <div class="more disNon mL20 Contracts">
#        <div class="filter-option">
#         <input chktyp="jtype" chkval="Contract+Independent" class="fchk cjtype" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Contract_Independent-radius-30-jobs.html" rel="nofollow">
#          Contract Independent
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="jtype" chkval="Contract+W2" class="fchk cjtype" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Contract_W2-radius-30-jobs.html" rel="nofollow">
#          Contract W2
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="jtype" chkval="C2H+Independent" class="fchk cjtype" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-C2H_Independent-radius-30-jobs.html" rel="nofollow">
#          C2H Independent
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="jtype" chkval="C2H+W2" class="fchk cjtype" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-C2H_W2-radius-30-jobs.html" rel="nofollow">
#          C2H W2
#         </a>
#        </div>
#       </div>
#       <div class="default" style="display:none;">
#        <div class="filter-option">
#         <input chktyp="jtype" chkval="Third+Party" class="cfchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Third_Party-radius-30-jobs.html" rel="nofollow">
#          Third Party
#         </a>
#         <a class="thirdPartyModal" data-target="#3rdparty" data-toggle="modal">
#          <i class="icon icon-question-mark">
#          </i>
#         </a>
#        </div>
#       </div>
#       <div class="more disNon mL20 Party">
#        <div class="filter-option">
#         <input chktyp="jtype" chkval="Contract+Corp%26%2345To%26%2345Corp" class="fchk cjtype" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-Contract_Corp%26%2345To%26%2345Corp-radius-30-jobs.html" rel="nofollow">
#          Contract Corp-To-Corp
#         </a>
#        </div>
#        <div class="filter-option">
#         <input chktyp="jtype" chkval="C2H+Corp%26%2345To%26%2345Corp" class="fchk cjtype" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-jtype-C2H_Corp%26%2345To%26%2345Corp-radius-30-jobs.html" rel="nofollow">
#          C2H Corp-To-Corp
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- EMPLOYMENT_TYPE Section End from here -->
#      <!-- Telecommute Option Start from here -->
#      <div class="page-header-custom" id="telecommuteOption">
#       <div class="fh">
#        Telecommute
#        <span class="icon-filled-add-1 pull-right">
#        </span>
#       </div>
#       <div class="default" style="display:none;">
#        <div class="filter-option">
#         <input chktyp="dtco" chkval="true" class="fchk" type="checkbox"/>
#         <a href="https://www.dice.com/jobs/q-data_science-l-New_York%2C_NY-dtco-true-jtype-Full_Time-radius-30-jobs.html" rel="nofollow">
#          Yes
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- Telecommute Option End from here -->
#      <!-- search result left section for Distance, Title, Company, Employment Type and Company Segment End -->
#     </div>
#     <div class="col-md-9" id="resultSec">
#      <!-- search result section left End -->
#      <!-- search result section right Start -->
#      <!-- <div class="col-md-9" id="resultSec">  -->
#      <div class="jobs-page-header">
#       <!-- search result section right Header Start -->
#       <div class="row hidden-xs hidden-sm">
#        <div class="col-md-9">
#         <h1 class="pull-left h1 jobs-page-header-h1">
#          Full-Time data science jobs in New York, NY
#         </h1>
#        </div>
#        <div class="col-md-3">
#         <!-- Replacing for job notification page -->
#         <a class="btn btn-lg dice-btn-secondary job-alert pull-right" data-target="#myModal" data-toggle="modal">
#          <span class="icon-mail-1">
#          </span>
#          Create Job Alert
#         </a>
#        </div>
#       </div>
#       <div class="row visible-xs visible-sm">
#        <div class="col-md-12">
#         <h2 class="h1 jobs-page-header-h1">
#          Full-Time data science jobs in New York, NY
#         </h2>
#        </div>
#       </div>
#       <div class="row visible-xs visible-sm">
#        <div class="col-md-12 col-lg-12">
#         <h4 class="pull-left posiCount sort mobile">
#          <span>
#           1 - 30
#          </span>
#          of
#          <span>
#           2963
#          </span>
#          positions
#         </h4>
#        </div>
#       </div>
#       <div class="row visible-xs visible-sm hidden-md hidden-lg mobile-btns">
#        <div class="col-md-12">
#         <a class="btn dice-btn-secondary" onclick="toggleFilter()">
#          <span class="icon-filter-3">
#          </span>
#          Filter
#         </a>
#         <!-- Replacing for job notification page -->
#         <a class="btn dice-btn-secondary job-alert pull-right" data-target="#myModal" data-toggle="modal">
#          <span class="icon-mail-1">
#          </span>
#          Create Job Alert
#         </a>
#        </div>
#       </div>
#       <div class="row hidden-xs hidden-sm">
#        <div class="col-md-12 col-lg-12">
#         <h4 class="pull-left posiCount sort">
#          <span>
#           1 - 30
#          </span>
#          of
#          <span>
#           2963
#          </span>
#          positions
#         </h4>
#        </div>
#       </div>
#       <div class="row">
#        <div class="col-md-12 col-lg-12">
#         <hr/>
#        </div>
#        <div class="hidden-xs hidden-sm col-md-6 col-lg-6 mT10">
#         <div id="dice_paging_top">
#         </div>
#        </div>
#        <div class="col-sm-3 col-xs-3 col-md-2 col-lg-3 mT10">
#        </div>
#        <div class="col-xs-9 col-sm-9 col-md-3 col-lg-3 mT10 mB5">
#         <h4 class="sort" style="font-size:13px;">
#          <span class="hidden-xs hidden-sm">
#           Sort by:
#          </span>
#          <span id="sortby">
#           <span>
#            relevance
#           </span>
#           |
#           <a class="dice-btn-link" href="#" id="sort-by-date-link" rel="nofollow">
#            date
#           </a>
#           <span id="distancepipe" style="display:none">
#            |
#           </span>
#           <a class="dice-btn-link" href="#" id="sort-by-distance-link" rel="nofollow" style="display:none">
#            distance
#           </a>
#          </span>
#         </h4>
#        </div>
#       </div>
#       <!-- search result section right Header End -->
#      </div>
#      <div class="row" id="search-results-control">
#       <div class="col-md-9">
#        <!-- search result section right Content Block  Start  -->
#        <div id="serp">
#         <!-- starting Div for viewed Job -->
#         <div class="complete-serp-result-div" id="viewedIde0788f7f50d315de25ee1d91fe85d44a">
#          <div class="serp-result-content">
#           <input id="featureIde0788f7f50d315de25ee1d91fe85d44a" type="hidden" value="false"/>
#           <div class="logo-section hidden-xs">
#            <div class="logopath">
#             <a class="circle" href="https://www.dice.com/company/amazon20" style="display:none;">
#              A
#             </a>
#             <a href="https://www.dice.com/company/amazon20">
#              <img alt="Amazon" onerror="errorImg(this)" src="//assets.dice.com/external/images/empLogos/2b1e93fe4d46ef6752eb8c1b080d6c1d.jpg"/>
#             </a>
#            </div>
#           </div>
#           <h3>
#            <a class="dice-btn-link" href="https://www.dice.com/jobs/detail/Software-Development-Engineer%2C-Data-Science-Amazon-Newark-NJ-07101/amazon20/446982?icid=sr1-1p&amp;q=data science&amp;l=New York, NY" id="position0" onclick="cookieJobID('e0788f7f50d315de25ee1d91fe85d44a');setCookieViewedJobs('e0788f7f50d315de25ee1d91fe85d44a');" title="Software Development Engineer, Data Science" value="e0788f7f50d315de25ee1d91fe85d44a">
#             Software Development Engineer, Data Science
#             <span class="job-status-indicator icon-preview-1 visited ">
#             </span>
#             <span class="job-status-indicator icon-star-1 saveaction" id="e0788f7f50d315de25ee1d91fe85d44a" issavedjob="false">
#             </span>
#            </a>
#           </h3>
#           <div class="shortdesc">
#            Audible, Inc. is the world's largest seller and producer of downloadable audiobooks, a curator of short-form audio...
#           </div>
#           <ul class="list-inline details row">
# ...
#          </span>
#         </div>
#        </div>
#        <div class="form-group">
#         <div class="col-md-8">
#          <p class="pull-right">
#           <a href="http://www.dice.com/profman/resetPassword.jsp" target="_blank">
#            Forgot Password?
#           </a>
#          </p>
#         </div>
#        </div>
#       </form>
#      </div>
#      <div class="modal-footer footr" style="margin-top: 0;">
#       <div class="row">
#        <!-- <div class="col-sm-4"><p class=""><a href="http://www.dice.com/profman/resetPassword.jsp" target="_blank">Forgot Password?</a></p></div> -->
#        <div class="col-md-2">
#         <button class="btn btn-primary btn-lg" id="signBtnId" onclick="loginSubmit();" style="background-color: #006699" type="button">
#          Sign In
#         </button>
#        </div>
#        <div class="col-md-1">
#         <span id="loginLoaderImg" style="display: none; line-height: 38px;">
#          <img alt="Loading" src="//assets.dice.com/techpro/img/loading24px.gif"/>
#         </span>
#        </div>
#        <div class="col-md-2" id="skipBtn">
#        </div>
#        <div class="col-md-7">
#         <span class="pull-right" style="line-height: 38px;">
#          Don't have an account?
#          <a href="/register" id="register" onclick="return redirectURLCookie();" target="_parent">
#           Register
#          </a>
#         </span>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div aria-hidden="true" aria-labelledby="myModalLabel" class="modal fade" id="myModal" role="dialog" tabindex="-1">
#    <div class="modal-dialog">
#     <div class="modal-content">
#      <div class="modal-header">
#       <button aria-hidden="true" class="close" data-dismiss="modal" type="button">
#        ×
#       </button>
#       <h3 class="modal-title" id="myModalLabel">
#        Create an alert
#       </h3>
#      </div>
#      <div class="modal-body alert_body">
#       <form class="form-horizontal" id="CreateAlertForm_1" name="jobAlert">
#        <div class="form-group">
#         <div class="col-sm-2">
#          <label class="control-label">
#           Title
#          </label>
#         </div>
#         <div class="col-sm-10">
#          <input class="form-control" id="alertname" maxlength="100" name="name" placeholder="Enter a title" type="text" value="data science"/>
#          <div class="help-block hidden validTitle">
#           Please enter a title.
#          </div>
#         </div>
#        </div>
#        <div class="form-group" style="margin-bottom: 0px;">
#         <div class="col-sm-2">
#          <label class="control-label" for="">
#           Email
#          </label>
#         </div>
#         <div class="col-sm-10">
#          <input class="form-control" id="alertEmail" name="email" placeholder="Enter an email" type="text" value=""/>
#          <input class="form-control hidden" id="alertDisabled" name="disabled" type="text" value="false"/>
#          <input class="form-control hidden" id="emailFrequency" name="emailFrequency" type="text" value="never"/>
#          <div class="help-block hidden validEmail">
#           Please enter a valid email (email@domain.com).
#          </div>
#         </div>
#        </div>
#       </form>
#      </div>
#      <div class="modal-footer alert_footer">
#       <div class="row">
#        <div class="col-md-12">
#         <button class="btn btn-primary" onclick="crateJobAlter()" style="background:#006699;" type="button">
#          Create Alert
#         </button>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script src="//ajax.googleapis.com/ajax/libs/jquery/1.12.0/jquery.min.js">
#   </script>
#   <script type="text/javascript">
#    var diceJSON = {page : 1, pageCount : 99 , limit : 30} ;
# 		function errorImg(obj) {
# 			$(obj).hide();
# 			$(obj).parent().siblings('.circle').show();
# 		}
#   </script>
#   <script>
#    _satellite.pageBottom()
#   </script>
#   <script>
#    $.get("https://www.dice.com/refresh/seeker");
#   </script>
#   <script>
#    $.get("https://www.dice.com/refresh/DGL");
#   </script>
#   <!-- <script type="text/javascript" src="//maps.googleapis.com/maps/api/js?sensor=true&libraries=places&v=3.22"></script> -->
#   <script src="//maps.googleapis.com/maps/api/js?libraries=places&amp;v=3.23&amp;key=AIzaSyBIdPte3BjiTJYhsuLfzBJgUAHGQx_l07U" type="text/javascript">
#   </script>
#   <script src="//assets.dice.com/techpro/js/global/login-dialog.js">
#   </script>
#   <script src="https://apis.google.com/js/api:client.js">
#   </script>
#   <script type="text/javascript">
#    $(document).ready(footercollapse);
# $(window).resize(footercollapse);
#
# function footercollapse() {
# 	//deleteCookie('DJV_UNREGISTERED', '/');
# 	if ((window.innerWidth || document.body.offsetWidth) < 992) {
# 		$('#dice-sites').removeClass('in').addClass('collapse');
# 		$('#dice-services').removeClass('in').addClass('collapse');
# 		$('#learn-about-dice').removeClass('in').addClass('collapse');
# 	} else {
# 		$('#dice-sites').addClass('in').removeClass('collapse').removeAttr('style');
# 		$('#dice-services').addClass('in').removeClass('collapse').removeAttr('style');
# 		$('#learn-about-dice').addClass('in').removeClass('collapse').removeAttr('style');
# 	}
# }
#   </script>
#   <script>
#    // Include the UserVoice JavaScript SDK (only needed once on a page)
# UserVoice=window.UserVoice||[];(function(){var uv=document.createElement('script');uv.type='text/javascript';uv.async=true;uv.src='//widget.uservoice.com/xNTaf4xWM431ZBy72jhpyw.js';var s=document.getElementsByTagName('script')[0];s.parentNode.insertBefore(uv,s)})();
#
# //
# // UserVoice Javascript SDK developer documentation:
# // https://www.uservoice.com/o/javascript-sdk
# //
#
# // Set colors
# UserVoice.push(['set', {
#   accent_color: '#66cc66',
#   trigger_color: 'white',
#   trigger_background_color: '#66cc66'
# }]);
#
# // Identify the user and pass traits
# // To enable, replace sample data with actual user traits and uncomment the line
# UserVoice.push(['identify', {
#   //email:      'john.doe@example.com', // Users email address
#   //name:       'John Doe', // Users real name
#   //created_at: 1364406966, // Unix timestamp for the date the user signed up
#   //id:         123, // Optional: Unique id of the user (if set, this should not change)
#   //type:       'Owner', // Optional: segment your users by type
#   //account: {
#   //  id:           123, // Optional: associate multiple users with a single account
#   //  name:         'Acme, Co.', // Account name
#   //  created_at:   1364406966, // Unix timestamp for the date the account was created
#   //  monthly_rate: 9.99, // Decimal; monthly rate of the account
#   //  ltv:          1495.00, // Decimal; lifetime value of the account
#   //  plan:         'Enhanced' // Plan name for the account
#   //}
# }]);
#
# // Add default trigger to the bottom-right corner of the window:
# UserVoice.push(['addTrigger', { mode: 'contact', trigger_position: 'center-right' }]);
#
# // Or, use your own custom trigger:
# //UserVoice.push(['addTrigger', '#id', { mode: 'contact' }]);
#
# // Autoprompt for Satisfaction and SmartVote (only displayed under certain conditions)
# UserVoice.push(['autoprompt', {}]);
#   </script>
#   <script type="text/javascript">
#    $('.nbt').unbind('click');
# 	$('.nbt').click(function(){
# 		var navbars = $('.navbar-collapse');
# 		var navtoggle = $(this).attr('data-target');
#
# 		for(var i=0; i< navbars.length;i++){
# 			if(navtoggle != '#'+ $(navbars[i]).attr('id')
# 				&& $(navbars[i]).hasClass('slideUp')){
# 				$(navbars[i]).slideUp();
# 				$(navbars[i]).removeClass('slideUp');
# 			}
# 		}
#
# 		if($(navtoggle).length > 0){
# 			if($(navtoggle).hasClass('hidden-xs')){
# 				$(navtoggle).removeClass('hidden-xs hidden-sm');
# 				$(navtoggle).css('display','none');
# 			}
#
# 			if($(navtoggle).hasClass('slideUp')){
# 				$(navtoggle).slideUp();
# 				$(navtoggle).removeClass('slideUp');
# 			}
# 			else{
# 				$(navtoggle).slideDown();
# 				$(navtoggle).addClass('slideUp');
# 			}
# 		}
# 		else{
# 			window.location.href = '/jobs';
# 		}
# 	});
#
# 	$('.smartMenu').unbind('click');
# 	$('.smartMenu').click(function(){
# 		var navtoggle = $(this).attr('data-target');
# 		var peopleId = $('#pid').val(), isNotificarion = false;;
# 		var searchableProfile = getCookie('searchableProfileId');
# 		if (this.id === 'smart-notification-toggle-link' || this.id === 'msmart-notification-toggle-link'){
# 			if (peopleId !== undefined || peopleId !== "" || peopleId !== null) {
# 				var notificationCookie = getCookie('notificationViewed'+peopleId);
# 				if (notificationCookie === null || notificationCookie === "" || notificationCookie === "null" || notificationCookie === undefined) {
# 					generateCookie('notificationViewed' + peopleId , false, 24 * 60 * 60 *1, '/');
# 				}
# 			}
# 			hideNotification();
# 			setNotification(this);
# 			isNotificarion = true;
# 		}
# 		if (!isNotificarion) {
# 			navToggleWin(this);
# 		}
# 	});
#
# 	function navToggleWin(obj) {
# 		var navtoggle = $(obj).attr('data-target');
# 		$(obj).find('.icon-arrow-67').hide();
# 		$(obj).find('.icon-arrow-68').hide();
# 		if($(navtoggle).length > 0){
# 			if($(navtoggle).hasClass('slideUp')){
# 				$(obj).find('.icon-arrow-67').show();
# 				$(navtoggle).slideUp(200);
# 				$(navtoggle).removeClass('slideUp');
# 			}
# 			else{
# 				$(obj).find('.icon-arrow-68').show();
# 				$(navtoggle).slideDown(200);
# 				$(navtoggle).addClass('slideUp');
# 			}
# 		}
# 	}
#
# 	//$(document).click(function(e) {
# 	$(document).on('click touchstart', 'html', function(e) {
# 		var target = (e && e.target) || (event && event.srcElement);
# 		if(isPopupClose(target)){
# 			$('.smartMenu').find('.icon-arrow-68').hide();
# 			$('.smartMenu').find('.icon-arrow-67').show();
# 			$('#smart-toggle').slideUp(200);
# 			$('#smart-toggle').removeClass('slideUp');
# 			$('#smart-notification').slideUp(200);
# 			$('#smart-notification').removeClass('slideUp');
# 			$('#msmart-notification').slideUp(200);
# 			$('#msmart-notification').removeClass('slideUp');
# 			$('#smart-toggle1').slideUp(200);
# 			$('#smart-toggle1').removeClass('slideUp');
# 		}
# 	});
#
# 	function isPopupClose(currentTarget) {
# 		var isClose = true, current_element = currentTarget,
# 			smartToggle = document.getElementById('smart-toggle'),
# 			smartToggleLink = document.getElementById('smart-toggle-link'),
# 			smartToggleCareer = document.getElementById('smart-toggle-Career'),
# 			smartNotificationToggleLink = document.getElementById('smart-notification-toggle-link'),
# 			msmartNotificationToggleLink = document.getElementById('msmart-notification-toggle-link');
#
# 		while(current_element && current_element != document.body) {
# 			if (current_element === smartToggle
# 			        || current_element === smartToggleLink
# 			        || current_element === smartToggleCareer
# 			        || current_element === smartNotificationToggleLink
# 			        || current_element === msmartNotificationToggleLink) {
# 				isClose = false;
# 				break;
# 			}
# 			current_element = current_element.parentNode;
# 		}
# 		return isClose;
# 	}
#
# 	function updateSession(updateVal) {
# 		var regExEmail = /^([a-zA-Z0-9_\-\.]+)@([a-zA-Z0-9_\-\.]+)\.([a-zA-Z]{2,5})$/;
# 		var diceCustomerName = $('#dice-customer-name').text();
# 		if(regExEmail.test(diceCustomerName) == true || diceCustomerName == "") {
# 			$.get("https://www.dice.com/refresh/session/"+updateVal+"/");
# 			$('#dice-customer-name').html(updateVal);
# 		}
# 	}
#
# 	hideNotification();
# 	var peopleId = $('#pid').val();
# 	var notificationViewed = getCookie('notificationViewed' + peopleId);
# 	function hideNotification() {
# 		notificationViewed = getCookie('notificationViewed' + peopleId);
# 		if (notificationViewed && notificationViewed != "false") {
# 			$('.notification-bubble').hide();
# 		}
# 	}
# 	setNotification();
# 	function setNotification(navtoggle) {
#         var nc = 0;
#         var searchableProfileId = getCookie('searchableProfileId');
# 		var profilecount = getCookie('profileCount');
# 		$('.notification-bubble').hide();
# 		if (searchableProfileId != null && searchableProfileId && nc === 0) { // searchable profile
# 			$.ajax({
# 				url: '/dashboard/notification/updateNotificationCount?id='+ searchableProfileId,
# 				async: false
# 			}).done(function(data) {
# 				nc = isNaN(data) ? 0 : parseInt(data);}).fail(function(xhr)  {
# 				nc  = 1;
# 			});
# 		}
# 		var marketValueCookie = null;
# 		var peopleId = getCookie('peopleId');
# 		try {
# 			marketValueCookie = getCookie('marketValueCookie'+peopleId);
# 			if(marketValueCookie == null){
# 				// incase cookie is not present assume that we have to show the notification
# 				marketValueCookie = "true";
# 			}
# 		} catch (ignore) {console.log(ignore);}
#
# 		if (searchableProfileId != null && searchableProfileId) { // searchable profile
# 			/* $.get('/dashboard/notification/updateNotificationCount?id='
# 				+ searchableProfileId, function(data, status) { */
# 				var bubbleCount = 1;
# 				if (marketValueCookie === "true") {
# 					bubbleCount = nc + 1;
# 				} else {
# 					$('.marketValue_notification').hide();
# 					bubbleCount = nc;
# 				}
# 				hideNotiMessages(nc, bubbleCount);
# 				if (nc != 0 && (notificationViewed === "false" || notificationViewed === null)) { //has some notification
# 					$('.notification-bubble').show();
# 					$('.notifi_skillopen').show();
# 				} else if (nc != 0) {
# 					$('.notifi_skillopen').show();
# 					$('.notification-bubble').hide();
# 				} else if (bubbleCount == 1) {
# 					$('.notification-bubble').show();
# 				} else { //no notification
# 					$('.notification-bubble').hide();
# 					$('.notifi_nonotification').show();
# 				}
# 				$('.smart-notification').show();
# 				if (navtoggle) {
# 					navToggleWin(navtoggle);
# 				}
# 			//});
# 		} else { //non-searchable or no profile
# 			var countVal = 1;
# 			if (marketValueCookie === "true" && (profilecount != null && profilecount != 0)) {
# 				countVal = parseInt(countVal) + 1;
# 			} else {
# 				$('.marketValue_notification').hide();
# 			}
# 			hideNotiMessages(0, countVal);
# 			$('.notification-bubble').show();
# 			if (profilecount != null && profilecount != 0) { // profile exists but not searchable
# 				if (searchableProfileId != null && searchableProfileId) {
# 					$('.notifi_nonotification').show();
# 				} else {
# 					$('.notifi_makeprofile').show();
# 				}
# 			} else { //profile not exists
# 				$('.notifi_createprofile').show();
# 			}
# 			$('.smart-notification').show();
# 			if (navtoggle) {
# 				navToggleWin(navtoggle);
# 			}
# 		}
# 	}
#
# 	function hideNotiMessages(count, bubbleCount) {
# 		$('.notificationCount').html(count);
# 		$('.bubbleCount').html(bubbleCount);
# 		$('.notifi_skillopen').hide();
# 		$('.notifi_createprofile').hide();
# 		$('.notifi_makeprofile').hide();
# 		$('.notifi_nonotification').hide();
# 	}
#   </script>
#   <script type="text/javascript">
#    /*$(document).ready(function(){
#     $("#welcome-modal").modal();
#   });
#   var date = new Date();
#   date.setTime(date.getTime()+(72*60*60*1000));
#   var expdate = "; expires="+date.toGMTString();
#   document.cookie = "wc_md=" + "1" + expdate + "; path=/";*/
#   </script>
#   <!-- WELCOME MODAL MARKUP -->
#   <div class="modal fade" id="welcome-modal">
#    <div class="modal-dialog">
#     <div class="modal-content">
#      <div class="modal-header">
#       <button aria-hidden="true" class="close" data-dismiss="modal" type="button">
#        ×
#       </button>
#      </div>
#      <div class="modal-body">
#       <p>
#        It's a little rough around the edges. If you find things we could do better, let us know at
#        <a href="mailto:newdicesupport@dice.com">
#         newdicesupport@dice.com
#        </a>
#        or give us a call at 888-321-DICE (3423)
#       </p>
#       <!--<button class="btn btn-default">Return to old Dice</button>-->
#       <button aria-hidden="true" class="btn btn-primary pull-right" data-dismiss="modal">
#        Continue with the new site
#       </button>
#       <div class="clearfix">
#       </div>
#      </div>
#     </div>
#     <!--  END MODAL CONTENT  -->
#    </div>
#    <!--  END MODAL DIALOG  -->
#   </div>
#   <!--  END THIRD PARTY MODAL  -->
#   <!-- END WELCOME MODAL MARKUP -->
#   <script src="//assets.dice.com/techpro/js/global/jobResults.min.js">
#   </script>
#   <script src="//cdn.jsdelivr.net/bootstrap.paginator/0.6.0/bootstrap-paginator.min.js">
#   </script>
#   <script src="//assets.dice.com/techpro/js/global/Chart.min.js">
#   </script>
#   <!-- footer section End -->
#  </body>
# </html>

# %%
def get_description()

# %%
## YOUR CODE HERE
#i = 0
#for d in soup.findAll('div'):
    #print(i, d)
    #print('\n')
    #i += 1



def extract_location_from_result(result):
    i = 0
    for d in soup.findAll('div'):
    print(i, d)
    print('\n')
    i += 1
    
    #return result.find
# Out:
#   File "<ipython-input-8-eec1327019b2>", line 13
#     print(i, d)
#         ^
# IndentationError: expected an indented block

# %%
def extract_company_from_result(result):
    return result.find

# %%
def extract_job_from_result(result):
    return result.find

# %%
def extract_salary_from_result(result):
    return result.find

# %% [markdown]
# Now, to scale up our scraping, we need to accumulate more results. We can do this by examining the URL above.
#
# - "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10"
#
# There are two query parameters here we can alter to collect more results, the `l=New+York` and the `start=10`. The first controls the location of the results (so we can try a different city). The second controls where in the results to start and gives 10 results (thus, we can keep incrementing by 10 to go further in the list).

# %% [markdown]
# ### Complete the following code to collect results from multiple cities and starting points.
# - Indeed.com only has salary information for an estimated 20% of job postings. You may want to add other cities to the list below to gather more data.
# - Remember to convert your salary to U.S. Dollars to match the other cities if the currency is different

# %%
url_template = "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l={}&start={}"
max_results_per_city = 100

results = []

for city in set(['New+York', 'Chicago', 'San+Francisco', 'Austin', 'Atlanta']):
    for start in range(0, max_results_per_city, 10):
        # Grab the results from the request (as above)
        # Append to the full set of results
        pass

# %% [markdown]
# #### Use the functions you wrote above to parse out the 4 fields - location, title, company and salary. Create a dataframe from the results with those 4 columns.

# %%
## YOUR CODE HERE

# %% [markdown]
# Lastly, we need to clean up salary data.
# 1. Some of the salaries are not yearly but hourly, these will be useful to us for now
# 2. The salaries are given as text and usually with ranges.
#
# #### Filter out the salaries that are not yearly (filter those that refer to hour)

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Write a function that takes a salary string and converts it to a number, averaging a salary range if necessary

# %%
## YOUR CODE HERE

# %% [markdown]
# ### Save your results as a CSV

# %%
## YOUR CODE HERE

# %% [markdown]
# # ![](https://ga-dash.s3.amazonaws.com/production/assets/logo-9f88ae6c9c3871690e33280fcf557f33.png) Project 4: Web Scraping & Logistic Regression
#
# ### Description
#
# This week we're learning about web scraping and logistic regression. Let's put these skills to the test!
#
# You're working as a data scientist for a contracting firm that's rapidly expanding. Now that they have their most valuable employee (you!), they need to leverage data to win more contracts. Your firm offers technology and scientific solutions and wants to be competitive in the hiring market. Your principal thinks the best way to gauge salary amounts is to take a look at what industry factors influence the pay scale for these professionals.
#
# Aggregators like [Indeed.com](https://www.indeed.com) regularly pool job postings from a variety of markets and industries. Your job is to understand what factors most directly impact data science salaries and effectively, accurately find appropriate data science related jobs in your metro region.
#
# #### Project Summary
#
# In this project, we will practice two major skills. Collecting data by scraping a website and then building a binary predictor with Logistic Regression.
#
# We are going to collect salary information on data science jobs in a variety of markets. Then using the location, title, and summary of the job, we will attempt to predict a corresponding salary for that job. While most listings DO NOT come with salary information (as you will see in this exercise), being to able extrapolate or predict the expected salaries for other listings will be extremely useful for negotiations :)
#
# Normally we could use regression for this task; however, instead we will convert this into a classification problem and use Logistic Regression.
#
# - **Question**: Why would we want this to be a classification problem?
# - **Answer**: While more precision may be better, there is a fair amount of natural variance in job salaries; therefore, predicting a range (e.g. high or low) may be useful.
#
# The first part of assignment will be focused on scraping data, and the second will be focused on using the listings with salary information to build a model and predict salaries.
#
# Your job is to:
#
# 1. Collect data on data science salary trends from a job listings aggregator for your analysis.
#   - Select and parse data from at least ~1000 postings for jobs, potentially from multiple location searches.
# 2. Find out what factors most directly impact salaries (title, location, department, etc.). In this case, we do not want to predict mean salary as would be done in a regression. Your boss believes that salary is better represented in categories than continuously
#   - Test, validate, and describe your models. What factors predict salary category? How do your models perform?
# 3. Prepare a presentation for your Principal detailing your analysis.
#
# **BONUS PROBLEMS:**
# 1. Your boss would rather tell a client incorrectly that they would get a lower salary job than tell a client incorrectly that they would get a high salary job. Adjust one of your logistic regression models to ease her mind, and explain what it is doing and any tradeoffs. Plot the ROC curve.
# 2. Text variables and regularization:
#   - **Part 1**: Job descriptions contain more potentially useful information you could leverage. Use the job summary to find words you think would be important and add them as predictors to a model.
#   - **Part 2**: Gridsearch parameters for Ridge and Lasso for this model and report the best model.
#
#
# **Goal:** Scrape & clean data, run logistic regression, derive insights, present findings.
#
# ---
#
# ### Requirements
#
# - Scrape and prepare your data using BeautifulSoup.
# - A team Jupyter Notebook with your regression analysis for a peer audience of data scientists.
# - An individual blog post describing your findings, with two sections: the first for a non-technical audience, and the second for data scientist peers.
# - A five-minute in-class presentation, delivered as if you were presenting your findings to the principal who tasked you with this investigation.
#
# Please submit a link to your GitHub project repo and blog posts by the start of class on Wednesday (10/19).
#
# Presentations will be on Friday (10/21); there will be some in-class time on Thursday and Friday to prepare.
#
# ---
#
# ### Suggested Ways to Get Started
#
# - Read the docs for whatever technologies you use. Most of the time, there is a tutorial that you can follow, but not always, and learning to read documentation is crucial to your success!
# - Document **everything**.
#
# ### Additional Resources
# - [Advice on How to Write for a Non-Technical Audience](http://programmers.stackexchange.com/questions/11523/explaining-technical-things-to-non-technical-people)
# - [Documentation for BeautifulSoup can be found here](http://www.crummy.com/software/BeautifulSoup/).
#
# ---
#
# ### Project Feedback + Evaluation
#
# [Attached here is a complete rubric for this project.](./project-04-rubric.md)
#
# Your instructors will score each of your technical requirements using the scale below:
#
#     Score | Expectations
#     ----- | ------------
#     **0** | _Incomplete._
#     **1** | _Does not meet expectations._
#     **2** | _Meets expectations, good job!_
#     **3** | _Exceeds expectations, you wonderful creature, you!_
#
#  This will serve as a helpful overall gauge of whether you met the project goals, but __the more important scores are the individual ones__ above, which can help you identify where to focus your efforts for the next project!
# # ![](https://ga-dash.s3.amazonaws.com/production/assets/logo-9f88ae6c9c3871690e33280fcf557f33.png) Project 4: Web Scraping & Logistic Regression
#
# ### Description
#
# This week we're learning about web scraping and logistic regression. Let's put these skills to the test!
#
# You're working as a data scientist for a contracting firm that's rapidly expanding. Now that they have their most valuable employee (you!), they need to leverage data to win more contracts. Your firm offers technology and scientific solutions and wants to be competitive in the hiring market. Your principal thinks the best way to gauge salary amounts is to take a look at what industry factors influence the pay scale for these professionals.
#
# Aggregators like [Indeed.com](https://www.indeed.com) regularly pool job postings from a variety of markets and industries. Your job is to understand what factors most directly impact data science salaries and effectively, accurately find appropriate data science related jobs in your metro region.
#
# #### Project Summary
#
# In this project, we will practice two major skills. Collecting data by scraping a website and then building a binary predictor with Logistic Regression.
#
# We are going to collect salary information on data science jobs in a variety of markets. Then using the location, title, and summary of the job, we will attempt to predict a corresponding salary for that job. While most listings DO NOT come with salary information (as you will see in this exercise), being to able extrapolate or predict the expected salaries for other listings will be extremely useful for negotiations :)
#
# Normally we could use regression for this task; however, instead we will convert this into a classification problem and use Logistic Regression.
#
# - **Question**: Why would we want this to be a classification problem?
# - **Answer**: While more precision may be better, there is a fair amount of natural variance in job salaries; therefore, predicting a range (e.g. high or low) may be useful.
#
# The first part of assignment will be focused on scraping data, and the second will be focused on using the listings with salary information to build a model and predict salaries.
#
# Your job is to:
#
# 1. Collect data on data science salary trends from a job listings aggregator for your analysis.
#   - Select and parse data from at least ~1000 postings for jobs, potentially from multiple location searches.
# 2. Find out what factors most directly impact salaries (title, location, department, etc.). In this case, we do not want to predict mean salary as would be done in a regression. Your boss believes that salary is better represented in categories than continuously
#   - Test, validate, and describe your models. What factors predict salary category? How do your models perform?
# 3. Prepare a presentation for your Principal detailing your analysis.
#
# **BONUS PROBLEMS:**
# 1. Your boss would rather tell a client incorrectly that they would get a lower salary job than tell a client incorrectly that they would get a high salary job. Adjust one of your logistic regression models to ease her mind, and explain what it is doing and any tradeoffs. Plot the ROC curve.
# 2. Text variables and regularization:
#   - **Part 1**: Job descriptions contain more potentially useful information you could leverage. Use the job summary to find words you think would be important and add them as predictors to a model.
#   - **Part 2**: Gridsearch parameters for Ridge and Lasso for this model and report the best model.
#
#
# **Goal:** Scrape & clean data, run logistic regression, derive insights, present findings.
#
# ---
#
# ### Requirements
#
# - Scrape and prepare your data using BeautifulSoup.
# - A team Jupyter Notebook with your regression analysis for a peer audience of data scientists.
# - An individual blog post describing your findings, with two sections: the first for a non-technical audience, and the second for data scientist peers.
# - A five-minute in-class presentation, delivered as if you were presenting your findings to the principal who tasked you with this investigation.
#
# Please submit a link to your GitHub project repo and blog posts by the start of class on Wednesday (10/19).
#
# Presentations will be on Friday (10/21); there will be some in-class time on Thursday and Friday to prepare.
#
# ---
#
# ### Suggested Ways to Get Started
#
# - Read the docs for whatever technologies you use. Most of the time, there is a tutorial that you can follow, but not always, and learning to read documentation is crucial to your success!
# - Document **everything**.
#
# ### Additional Resources
# - [Advice on How to Write for a Non-Technical Audience](http://programmers.stackexchange.com/questions/11523/explaining-technical-things-to-non-technical-people)
# - [Documentation for BeautifulSoup can be found here](http://www.crummy.com/software/BeautifulSoup/).
#
# ---
#
# ### Project Feedback + Evaluation
#
# [Attached here is a complete rubric for this project.](./project-04-rubric.md)
#
# Your instructors will score each of your technical requirements using the scale below:
#
#     Score | Expectations
#     ----- | ------------
#     **0** | _Incomplete._
#     **1** | _Does not meet expectations._
#     **2** | _Meets expectations, good job!_
#     **3** | _Exceeds expectations, you wonderful creature, you!_
