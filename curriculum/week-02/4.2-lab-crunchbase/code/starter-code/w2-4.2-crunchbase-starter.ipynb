# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# read in the raw data from the github url

df = pd.read_csv("https://raw.githubusercontent.com/suneel0101/lesson-plan/master/crunchbase_monthly_export.csv")

# %%
df.head()
# Out:
#                          permalink                name  \
# 0   /organization/canal-do-credito    Canal do Credito
# 1            /organization/waywire            #waywire
# 2  /organization/tv-communications  &TV Communications
# 3    /organization/rock-your-paper   'Rock' Your Paper
# 4   /organization/in-touch-network   (In)Touch Network
#
#                        homepage_url  \
# 0  http://www.canaldocredito.com.br
# 1            http://www.waywire.com
# 2             http://enjoyandtv.com
# 3      http://www.rockyourpaper.org
# 4     http://www.InTouchNetwork.com
#
#                                        category_list          market   \
# 0               |Credit|Technology|Services|Finance|          Credit
# 1         |Entertainment|Politics|Social Media|News|   Entertainment
# 2                                            |Games|           Games
# 3                             |Publishing|Education|       Education
# 4  |Electronics|Guides|Coffee|Restaurants|Music|i...            Apps
#
#    funding_total_usd      status country_code state_code          region  \
# 0            750,000         NaN          BRA        NaN  Rio de Janeiro
# 1          1,750,000    acquired          USA         NY   New York City
# 2          4,000,000   operating          USA         CA     Los Angeles
# 3             40,000   operating          EST        NaN         Tallinn
# 4          1,500,000   operating          GBR        NaN          London
#
#              city  funding_rounds founded_at founded_month founded_quarter  \
# 0  Belo Horizonte               1        NaN           NaN             NaN
# 1        New York               1     6/1/12       2012-06         2012-Q2
# 2     Los Angeles               2        NaN           NaN             NaN
# 3         Tallinn               1   10/26/12       2012-10         2012-Q4
# 4          London               1     4/1/11       2011-04         2011-Q2
#
#    founded_year first_funding_at last_funding_at  Unnamed: 18
# 0           NaN           1/1/10          1/1/10          NaN
# 1        2012.0          6/30/12         6/30/12          NaN
# 2           NaN           6/4/10         9/23/10          NaN
# 3        2012.0           8/9/12          8/9/12          NaN
# 4        2011.0           4/1/11          4/1/11          NaN

# %% [markdown]
# #### 1. Clean the data. Use .apply and lambda functions where you can

# %%
# rename the columns to remove spaces and extra characters
df.columns = ['permalink','name','homepage_url', 'category_list', 'market', 'funding_total_usd', 'status', 'country_code', 'state_code', 'region', 'city', 'funding_rounds', 'founded_at', 'founded_month','founded_quarter','founded_year','first_funding_at', 'last_funding_at','undefined']
df.head()
# Out:
#                          permalink                name  \
# 0   /organization/canal-do-credito    Canal do Credito
# 1            /organization/waywire            #waywire
# 2  /organization/tv-communications  &TV Communications
# 3    /organization/rock-your-paper   'Rock' Your Paper
# 4   /organization/in-touch-network   (In)Touch Network
#
#                        homepage_url  \
# 0  http://www.canaldocredito.com.br
# 1            http://www.waywire.com
# 2             http://enjoyandtv.com
# 3      http://www.rockyourpaper.org
# 4     http://www.InTouchNetwork.com
#
#                                        category_list           market  \
# 0               |Credit|Technology|Services|Finance|          Credit
# 1         |Entertainment|Politics|Social Media|News|   Entertainment
# 2                                            |Games|           Games
# 3                             |Publishing|Education|       Education
# 4  |Electronics|Guides|Coffee|Restaurants|Music|i...            Apps
#
#   funding_total_usd     status country_code state_code          region  \
# 0          750,000         NaN          BRA        NaN  Rio de Janeiro
# 1        1,750,000    acquired          USA         NY   New York City
# 2        4,000,000   operating          USA         CA     Los Angeles
# 3           40,000   operating          EST        NaN         Tallinn
# 4        1,500,000   operating          GBR        NaN          London
#
#              city  funding_rounds founded_at founded_month founded_quarter  \
# 0  Belo Horizonte               1        NaN           NaN             NaN
# 1        New York               1     6/1/12       2012-06         2012-Q2
# 2     Los Angeles               2        NaN           NaN             NaN
# 3         Tallinn               1   10/26/12       2012-10         2012-Q4
# 4          London               1     4/1/11       2011-04         2011-Q2
#
#    founded_year first_funding_at last_funding_at  undefined
# 0           NaN           1/1/10          1/1/10        NaN
# 1        2012.0          6/30/12         6/30/12        NaN
# 2           NaN           6/4/10         9/23/10        NaN
# 3        2012.0           8/9/12          8/9/12        NaN
# 4        2011.0           4/1/11          4/1/11        NaN

# %%
df.describe()
# Out:
#        funding_rounds  founded_year  undefined
# count    44950.000000  35226.000000        0.0
# mean         1.681135   2007.083461        NaN
# std          1.269198      7.522161        NaN
# min          1.000000   1900.000000        NaN
# 25%          1.000000           NaN        NaN
# 50%          1.000000           NaN        NaN
# 75%          2.000000           NaN        NaN
# max         16.000000   2014.000000        NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44950 entries, 0 to 44949
# Data columns (total 19 columns):
# permalink            44950 non-null object
# name                 44949 non-null object
# homepage_url         41914 non-null object
# category_list        40997 non-null object
# market               40997 non-null object
# funding_total_usd    0 non-null float64
# status               42208 non-null object
# country_code         40805 non-null object
# state_code           27773 non-null object
# region               39615 non-null object
# city                 40109 non-null object
# funding_rounds       44950 non-null int64
# founded_at           35292 non-null object
# founded_month        35226 non-null object
# founded_quarter      35226 non-null object
# founded_year         35226 non-null float64
# first_funding_at     44950 non-null object
# last_funding_at      44950 non-null object
# undefined            0 non-null float64
# dtypes: float64(3), int64(1), object(15)
# memory usage: 6.5+ MB

# %%
df.get_dtype_counts()
# Out:
# float64     2
# int64       1
# object     16
# dtype: int64

# %%
df.columns
# Out:
# Index([u'permalink', u'name', u'homepage_url', u'category_list', u'market',
#        u'funding_total_usd', u'status', u'country_code', u'state_code',
#        u'region', u'city', u'funding_rounds', u'founded_at', u'founded_month',
#        u'founded_quarter', u'founded_year', u'first_funding_at',
#        u'last_funding_at', u'undefined'],
#       dtype='object')

# %%
# convert the funding, year founded, and funding_rounds columns to integers
#df['funding_total_usd'] = df.funding_total_usd.str.replace(',','')
#df['funding_total_usd'] = df['funding_total_usd'].astype('int')
#df['funding_total_usd'] = df.apply(lambda x: int(x))
#df.funding_total_usd = df.funding_total_usd.map(int)
#df['funding_total_usd'] = df['funding_total_usd'].apply(lambda x: int(x) if str.isdigit(x) else np.nan)
df['funding_total_usd'] = df.funding_total_usd.str.replace('-',np.nan)

#print (df[ pd.to_numeric(df['funding_total_usd'], errors='coerce').isnull()])

# %%
df.head(400)
# Out:
#                                  permalink                     name  \
# 0           /organization/canal-do-credito         Canal do Credito
# 1                    /organization/waywire                 #waywire
# 2          /organization/tv-communications       &TV Communications
# 3            /organization/rock-your-paper        'Rock' Your Paper
# 4           /organization/in-touch-network        (In)Touch Network
# 5                    /organization/n-plusn                   #NAME?
# 6               /organization/club-domains            .Club Domains
# 7               /organization/fox-networks            .Fox Networks
# 8                    /organization/0-6-com                  0-6.com
# 9           /organization/004-technologies         004 Technologies
# 10                    /organization/0xdata                   0xdata
# 11               /organization/1-2-3-listo              1,2,3 Listo
# 12                   /organization/1-4-all                  1-4 All
# 13             /organization/1-800-dentist            1-800-DENTIST
# 14             /organization/1-800-doctors            1-800-DOCTORS
# 15          /organization/1-618-technology         1.618 Technology
# 16               /organization/10-20-media              10-20 Media
# 17                /organization/1000-corks               1000 Corks
# 18              /organization/1000-markets             1000 Markets
# 19         /organization/1000jobboersen-de        1000jobboersen.de
# 20              /organization/1000memories             1000memories
# 21           /organization/1000museums-com          1000museums.com
# 22                /organization/1001-menus               1001 Menus
# 23                   /organization/1006-tv                  1006.tv
# 24                  /organization/100du-tv                 100du.tv
# 25                  /organization/100e-com                 100e.com
# 26                   /organization/100plus                  100Plus
# 27                  /organization/1010data                 1010data
# 28              /organization/10bestthings             10BestThings
# 29                     /organization/10sec                    10sec
# ..                                     ...                      ...
# 370                   /organization/8hands                   8hands
# 371  /organization/8minutenergy-renewables  8minutenergy Renewables
# 372                /organization/8th-story                8th Story
# 373              /organization/alvenda-inc                8thBridge
# 374                  /organization/8tracks            8tracks Radio
# 375                    /organization/8trip                    8Trip
# 376                /organization/8villages                8villages
# 377                  /organization/8x8-inc                  8x8 Inc
# 378              /organization/908-devices              908 Devices
# 379       /organization/90sec-technologies       90sec Technologies
# 380        /organization/91-boyuan-wireles        91 Boyuan Wireles
# 381                  /organization/91-golf                  91 Golf
# 382              /organization/91-wireless              91 Wireless
# 383                 /organization/911-pets                 911 Pets
# 384           /organization/9158-julur-com           9158 Julur.com
# 385             /organization/91datong-com             91datong.com
# 386                /organization/91jinrong                91JinRong
# 387            /organization/99-fahrenheit            99 Fahrenheit
# 388                    /organization/99-co                    99.co
# 389                   /organization/99bill                   99Bill
# 390         /organization/99degrees-custom         99degrees Custom
# 391                /organization/99designs                99designs
# 392                /organization/99dresses                99dresses
# 393                 /organization/99inn-cc                 99inn.cc
# 394               /organization/99presents               99Presents
# 395             /organization/99taojin-com             99taojin.com
# 396                  /organization/99tests                  99tests
# 397               /organization/99times-cn               99times.cn
# 398      /organization/9car-technology-llc      9car Technology LLC
# 399                 /organization/9diamond                 9DIAMOND
#
#                           homepage_url  \
# 0     http://www.canaldocredito.com.br
# 1               http://www.waywire.com
# 2                http://enjoyandtv.com
# 3         http://www.rockyourpaper.org
# 4        http://www.InTouchNetwork.com
# 5                     http://plusn.com
# 6                     http://nic.club/
# 7                http://www.dotfox.com
# 8                   http://www.0-6.com
# 9    http://004gmbh.de/en/004-interact
# 10               http://www.0xdata.com
# 11             http://www.123listo.com
# 12                                 NaN
# 13          http://www.1800dentist.com
# 14              http://1800doctors.com
# 15                                 NaN
# 16           http://www.10-20media.com
# 17                http://1000corks.com
# 18          http://www.1000markets.com
# 19        http://www.1000jobboersen.de
# 20             http://1000memories.com
# 21          http://www.1000museums.com
# 22                http://1001menus.com
# 23                 http://www.1006.tv/
# 24                http://www.100du.com
# 25                 http://www.100e.com
# 26              http://www.100plus.com
# 27             http://www.1010data.com
# 28             http://10bestthings.com
# 29                     https://10s.ec/
# ..                                 ...
# 370              http://www.8hands.com
# 371            http://8minutenergy.com
# 372            http://www.8thstory.com
# 373           http://www.8thbridge.com
# 374             http://www.8tracks.com
# 375                    http://8trip.cn
# 376           http://www.8villages.com
# 377                 http://www.8x8.com
# 378              http://908devices.com
# 379                http://www.90sec.me
# 380                  http://dev.91.com
# 381              http://www.91golf.com
# 382                  http://www.91.com
# 383                 http://911pets.us/
# 384               http://www.9158.com/
# 385           http://www.91datong.com/
# 386               http://91jinrong.com
# 387                                NaN
# 388                   http://www.99.co
# 389              http://www.99bill.com
# 390     http://www.99degreescustom.com
# 391               http://99designs.com
# 392               http://99dresses.com
# 393               http://www.99inn.cc/
# 394          http://www.99presents.com
# 395           http://www.99taojin.com/
# 396                 http://99tests.com
# 397              http://www.99times.cn
# 398          http://www.chejianghu.com
# 399           http://info.9diamond.com
#
#                                          category_list                 market  \
# 0                 |Credit|Technology|Services|Finance|                Credit
# 1           |Entertainment|Politics|Social Media|News|         Entertainment
# 2                                              |Games|                 Games
# 3                               |Publishing|Education|             Education
# 4    |Electronics|Guides|Coffee|Restaurants|Music|i...                  Apps
# 5                                           |Software|              Software
# 6                                           |Software|              Software
# 7                                        |Advertising|           Advertising
# 8                                        |Curated Web|           Curated Web
# 9                                           |Software|              Software
# 10                                         |Analytics|             Analytics
# 11                                        |E-Commerce|            E-Commerce
# 12                      |Entertainment|Games|Software|         Entertainment
# 13                               |Health and Wellness|   Health and Wellness
# 14                               |Health and Wellness|   Health and Wellness
# 15                                       |Real Estate|           Real Estate
# 16                                        |E-Commerce|            E-Commerce
# 17                                            |Search|                Search
# 18                       |Marketplaces|Art|E-Commerce|                   Art
# 19                                       |Curated Web|           Curated Web
# 20                                       |Curated Web|           Curated Web
# 21                                       |Curated Web|           Curated Web
# 22                      |Local Businesses|Restaurants|      Local Businesses
# 23                                       |Media|Games|                 Games
# 24                                       |Hospitality|           Hospitality
# 25                                         |Education|             Education
# 26                                         |Analytics|             Analytics
# 27                                          |Software|              Software
# 28                                       |Curated Web|           Curated Web
# 29        |Social Commerce|E-Commerce|Mobile Commerce|            E-Commerce
# ..                                                 ...                    ...
# 370          |Messaging|Social Media|Public Relations|             Messaging
# 371                                 |Clean Technology|      Clean Technology
# 372              |Lifestyle|Retail|E-Commerce|Fashion|            E-Commerce
# 373                       |Social Commerce|E-Commerce|            E-Commerce
# 374                                            |Music|                 Music
# 375                                           |Travel|                Travel
# 376                                           |Mobile|                Mobile
# 377                   |Telecommunications|Web Hosting|    Telecommunications
# 378                                    |Manufacturing|         Manufacturing
# 379  |Television|Weddings|Consumer Electronics|Mobi...                  Apps
# 380                                           |Mobile|                Mobile
# 381                                           |Mobile|                Mobile
# 382                                           |Mobile|                Mobile
# 383                                                NaN                    NaN
# 384                                     |Social Media|          Social Media
# 385                                          |Finance|               Finance
# 386                              |Finance|Curated Web|           Curated Web
# 387                                          |Finance|               Finance
# 388                                 |Local Businesses|      Local Businesses
# 389                              |Payments|E-Commerce|            E-Commerce
# 390                                                NaN                    NaN
# 391  |Marketplaces|Online Shopping|Crowdsourcing|De...         Crowdsourcing
# 392                             |File Sharing|Fashion|               Fashion
# 393                                       |Automotive|            Automotive
# 394                       |Social Commerce|E-Commerce|            E-Commerce
# 395                                    |Manufacturing|         Manufacturing
# 396                                         |Software|              Software
# 397                                       |E-Commerce|            E-Commerce
# 398                       |Automotive|Cars|E-Commerce|            Automotive
# 399                                       |E-Commerce|            E-Commerce
#
#     funding_total_usd     status country_code state_code  \
# 0             750000         NaN          BRA        NaN
# 1            1750000    acquired          USA         NY
# 2            4000000   operating          USA         CA
# 3              40000   operating          EST        NaN
# 4            1500000   operating          GBR        NaN
# 5             600000   operating          USA         NY
# 6            7000000         NaN          USA         FL
# 7            4912393      closed          ARG        NaN
# 8            2000000   operating          NaN        NaN
# 9           np.nan     operating          USA         IL
# 10           1700000   operating          USA         CA
# 11             40000   operating          CHL        NaN
# 12          np.nan     operating          USA         NC
# 13          np.nan     operating          USA         CA
# 14           1750000   operating          USA         NJ
# 15          np.nan     operating          USA         FL
# 16           2050000   operating          USA         MD
# 17             40000   operating          USA         OR
# 18            500000    acquired          NaN        NaN
# 19          np.nan     operating          DEU        NaN
# 20           2535000    acquired          USA         CA
# 21           4462651   operating          USA         WA
# 22           1869079   operating          FRA        NaN
# 23          10000000   operating          NaN        NaN
# 24           3000000   operating          NaN        NaN
# 25           3000000   operating          CHN        NaN
# 26           1250000    acquired          USA         CA
# 27          35000000   operating          USA         NY
# 28             50000      closed          USA         OH
# 29           1600000         NaN          NaN        NaN
# ..                ...        ...          ...        ...
# 370          1500000      closed          ISR        NaN
# 371         30000000   operating          USA         CA
# 372         np.nan     operating          USA         CA
# 373         15590000    acquired          USA         MN
# 374          1200000         NaN          USA         CA
# 375         24600000   operating          CHN        NaN
# 376           150000   operating          SGP        NaN
# 377         30608728    acquired          USA         CA
# 378         15100000   operating          USA         MA
# 379           100000   operating          ISR        NaN
# 380         20000000   operating          CHN        NaN
# 381           317460   operating          NaN        NaN
# 382         30000000    acquired          CHN        NaN
# 383         np.nan     operating          USA         TX
# 384          4502251   operating          NaN        NaN
# 385         63590263   operating          NaN        NaN
# 386         19790000   operating          CHN        NaN
# 387          1380700         NaN          ITA        NaN
# 388           560000   operating          SGP        NaN
# 389         81574271   operating          CHN        NaN
# 390           100000   operating          USA         MA
# 391         35000000   operating          USA         CA
# 392           105651   operating          AUS        NaN
# 393         75000000   operating          NaN        NaN
# 394            20000   operating          IND        NaN
# 395          7575757   operating          NaN        NaN
# 396           210000   operating          IND        NaN
# 397         np.nan        closed          CHN        NaN
# 398            80000      closed          CHN        NaN
# 399          9600000   operating          CHN        NaN
#
#                     region               city  funding_rounds founded_at  \
# 0           Rio de Janeiro     Belo Horizonte               1        NaN
# 1            New York City           New York               1     6/1/12
# 2              Los Angeles        Los Angeles               2        NaN
# 3                  Tallinn            Tallinn               1   10/26/12
# 4                   London             London               1     4/1/11
# 5            New York City           New York               1     1/1/12
# 6           Ft. Lauderdale       Oakland Park               1   10/10/11
# 7             Buenos Aires       Buenos Aires               1        NaN
# 8                      NaN                NaN               1     1/1/07
# 9    Springfield, Illinois          Champaign               1     1/1/10
# 10             SF Bay Area      Mountain View               1     1/1/11
# 11                Santiago         Las Condes               1     1/1/12
# 12          North Carolina  Connellys Springs               1        NaN
# 13             Los Angeles        Los Angeles               1     1/1/86
# 14                  Newark             Iselin               1     1/1/84
# 15                 Orlando            Orlando               1    12/7/13
# 16               Baltimore           Woodbine               4     1/1/01
# 17        Portland, Oregon        Lake Oswego               1     1/1/08
# 18                     NaN                NaN               1     1/1/09
# 19                  Berlin             Berlin               1        NaN
# 20             SF Bay Area      San Francisco               2     7/1/10
# 21                 Seattle           Bellevue               4     1/1/08
# 22                   Paris              Paris               2   11/20/10
# 23                 Beijing            Beijing               3     1/1/09
# 24                     NaN                NaN               2        NaN
# 25                 Beijing            Beijing               1        NaN
# 26             SF Bay Area      San Francisco               2    9/16/11
# 27           New York City           New York               1     1/1/00
# 28               Cleveland          Cleveland               1     4/1/09
# 29                     NaN                NaN               1     7/8/13
# ..                     ...                ...             ...        ...
# 370                   Asia                NaN               2        NaN
# 371             Sacramento             Folsom               1        NaN
# 372            Los Angeles        Los Angeles               1     1/1/13
# 373            Minneapolis        Minneapolis               3    11/1/08
# 374            SF Bay Area      San Francisco               1     8/8/08
# 375               Shanghai             Suzhou               1     1/1/11
# 376              Singapore          Singapore               1     6/1/11
# 377            SF Bay Area           San Jose               1     1/1/87
# 378                 Boston             Boston               2     1/1/12
# 379               Tel Aviv           Tel Aviv               1    6/30/13
# 380             Fuzhou Shi         Fuzhou Shi               1        NaN
# 381                    NaN                NaN               1        NaN
# 382             Fuzhou Shi         Fuzhou Shi               1     9/1/10
# 383                 Dallas             Dallas               1   12/28/13
# 384                    NaN                NaN               1        NaN
# 385                    NaN                NaN               1        NaN
# 386                Beijing            Beijing               3        NaN
# 387                  Milan             Milano               1    10/1/11
# 388              Singapore                NaN               1        NaN
# 389               Shanghai           Shanghai               4     1/1/05
# 390                 Boston           Lawrence               1        NaN
# 391            SF Bay Area      San Francisco               1     2/1/08
# 392                 Sydney             Sydney               2     1/1/10
# 393                    NaN                NaN               1        NaN
# 394               Vadodara           Vadodara               1    3/20/12
# 395                    NaN                NaN               1     1/1/09
# 396              Bangalore     Bangalore City               3    2/14/11
# 397               Shanghai           Shanghai               1     1/1/05
# 398                Beijing            Beijing               2   11/18/09
# 399               Shanghai           Shanghai               2     3/1/05
#
#     founded_month founded_quarter  founded_year first_funding_at  \
# 0             NaN             NaN           NaN           1/1/10
# 1         2012-06         2012-Q2        2012.0          6/30/12
# 2             NaN             NaN           NaN           6/4/10
# 3         2012-10         2012-Q4        2012.0           8/9/12
# 4         2011-04         2011-Q2        2011.0           4/1/11
# 5         2012-01         2012-Q1        2012.0          8/29/12
# 6         2011-10         2011-Q4        2011.0          5/31/13
# 7             NaN             NaN           NaN          1/16/07
# 8         2007-01         2007-Q1        2007.0          3/19/08
# 9         2010-01         2010-Q1        2010.0          7/24/14
# 10        2011-01         2011-Q1        2011.0           1/3/13
# 11        2012-01         2012-Q1        2012.0          2/18/13
# 12            NaN             NaN           NaN          4/21/13
# 13        1986-01         1986-Q1        1986.0          8/19/10
# 14        1984-01         1984-Q1        1984.0           3/2/11
# 15        2013-12         2013-Q4        2013.0          1/22/14
# 16        2001-01         2001-Q1        2001.0          6/18/09
# 17        2008-01         2008-Q1        2008.0          8/23/11
# 18        2009-01         2009-Q1        2009.0          5/15/09
# 19            NaN             NaN           NaN          9/16/11
# 20        2010-07         2010-Q3        2010.0           1/1/10
# 21        2008-01         2008-Q1        2008.0         10/14/09
# 22        2010-11         2010-Q4        2010.0         12/27/12
# 23        2009-01         2009-Q1        2009.0           1/1/11
# 24            NaN             NaN           NaN           1/7/08
# 25            NaN             NaN           NaN           1/1/06
# 26        2011-09         2011-Q3        2011.0          11/2/11
# 27        2000-01         2000-Q1        2000.0           3/8/10
# 28        2009-04         2009-Q2        2009.0           4/1/09
# 29        2013-07         2013-Q3        2013.0           5/8/14
# ..            ...             ...           ...              ...
# 370           NaN             NaN           NaN           1/1/08
# 371           NaN             NaN           NaN          6/17/14
# 372       2013-01         2013-Q1        2013.0           8/1/13
# 373       2008-11         2008-Q4        2008.0         11/16/09
# 374       2008-08         2008-Q3        2008.0          10/1/11
# 375       2011-01         2011-Q1        2011.0         11/13/13
# 376       2011-06         2011-Q2        2011.0          12/1/13
# 377       1987-01         1987-Q1        1987.0          10/3/11
# 378       2012-01         2012-Q1        2012.0           9/5/12
# 379       2013-06         2013-Q2        2013.0           9/1/13
# 380           NaN             NaN           NaN          12/1/11
# 381           NaN             NaN           NaN           1/1/12
# 382       2010-09         2010-Q3        2010.0          12/1/11
# 383       2013-12         2013-Q4        2013.0         12/28/13
# 384           NaN             NaN           NaN          12/1/10
# 385           NaN             NaN           NaN           3/1/11
# 386           NaN             NaN           NaN          10/1/11
# 387       2011-10         2011-Q4        2011.0         10/15/11
# 388           NaN             NaN           NaN           5/6/14
# 389       2005-01         2005-Q1        2005.0          4/26/06
# 390           NaN             NaN           NaN         10/30/13
# 391       2008-02         2008-Q1        2008.0          4/28/11
# 392       2010-01         2010-Q1        2010.0          3/30/12
# 393           NaN             NaN           NaN           8/1/12
# 394       2012-03         2012-Q1        2012.0           9/1/12
# 395       2009-01         2009-Q1        2009.0           1/1/11
# 396       2011-02         2011-Q1        2011.0          12/1/10
# 397       2005-01         2005-Q1        2005.0          8/23/10
# 398       2009-11         2009-Q4        2009.0         11/18/09
# 399       2005-03         2005-Q1        2005.0           1/1/05
#
#     last_funding_at  undefined
# 0            1/1/10        NaN
# 1           6/30/12        NaN
# 2           9/23/10        NaN
# 3            8/9/12        NaN
# 4            4/1/11        NaN
# 5           8/29/12        NaN
# 6           5/31/13        NaN
# 7           1/16/07        NaN
# 8           3/19/08        NaN
# 9           7/24/14        NaN
# 10           1/3/13        NaN
# 11          2/18/13        NaN
# 12          4/21/13        NaN
# 13          8/19/10        NaN
# 14           3/2/11        NaN
# 15          1/22/14        NaN
# 16         12/28/11        NaN
# 17          8/23/11        NaN
# 18          5/15/09        NaN
# 19          9/16/11        NaN
# 20          2/16/11        NaN
# 21          1/15/14        NaN
# 22         11/13/13        NaN
# 23          7/31/14        NaN
# 24          8/13/10        NaN
# 25           1/1/06        NaN
# 26         11/30/11        NaN
# 27           3/8/10        NaN
# 28           4/1/09        NaN
# 29           5/8/14        NaN
# ..              ...        ...
# 370          1/1/08        NaN
# 371         6/17/14        NaN
# 372          8/1/13        NaN
# 373         3/21/11        NaN
# 374         10/1/11        NaN
# 375        11/13/13        NaN
# 376         12/1/13        NaN
# 377         10/3/11        NaN
# 378         8/27/13        NaN
# 379          9/1/13        NaN
# 380         12/1/11        NaN
# 381          1/1/12        NaN
# 382         12/1/11        NaN
# 383        12/28/13        NaN
# 384         12/1/10        NaN
# 385          3/1/11        NaN
# 386         6/16/14        NaN
# 387        10/15/11        NaN
# 388          5/6/14        NaN
# 389        12/19/12        NaN
# 390        10/30/13        NaN
# 391         4/28/11        NaN
# 392          6/1/12        NaN
# 393          8/1/12        NaN
# 394          9/1/12        NaN
# 395          1/1/11        NaN
# 396         7/22/13        NaN
# 397         8/23/10        NaN
# 398          1/6/10        NaN
# 399          1/1/08        NaN
#
# [400 rows x 19 columns]

# %%
# convert category_list so that each cell is a list of categories

# %%
# use value_counts on market, status, and country_code to check for any repeats or misnamed entries

# %%
# BONUS: convert the date columns to appropriate datetime objects

# %% [markdown]
# #### 2. Using isnull(), take a subset of the dataframe that has no founded at date

# %% [markdown]
# #### 3. Create a new column, founded_year_x, that's a copy of founded_year. Then, replace all the missing values with either the mean , mode, or median of that column.
# Add a note explaining which statistic you picked and why:

# %% [markdown]
# #### 4. Take a subset of US-based companies using boolean selection

# %% [markdown]
# #### 5. Create a pivot table showing total, mean, and median funding amount by year

# %% [markdown]
# #### 6. Create a pivot table showing total, mean and median funding amount by market

# %% [markdown]
# #### 7. CHALLENGE: Using matplotlib, create a scatter plot showing funding amount on the y-axis, and first_funding_date on the x-axis
# (first_funding_date will need to be a timestamp)

# %% [markdown]
# #### 8. Here's the fun part. Create a hypothesis based on your data that you can reasonably test.
# For example: "Credit companies based in the US that only get 1 round of funding tend to receive more funding than companies based outside the US"
#
#
#
# When you have your hypothesis, write it below, and Slack it to the instructors so we can check in.

# %% [markdown]
# #### 9. Test your hypothesis.
#
# You'll need to evaluate your hypothesis using a t-test (see Monday's lecture 1.3), so make sure you have enough data compare samples. If your original hypothesis is too narrow, you may need to broaden the scope.

# %% [markdown]
# #### 10. CHALLENGE
# - Plot the distribution of both samples
# - Explain your results in one short sentence.
# - Explain your result in a slighly longer technical paragraph, touching on the statistics you presented.
# - Subset your findings: if you looked at a certain market in a certain geography, break it down by another variable (e.g number of funding rounds) and compare those samples.
